# %% [markdown]
# # Unit 5 — Searching & Complete Search Solutions
#
# Reference solutions for all nine exercises. Each is a runnable stdin program in `assets/<name>.py` (run it with `python assets/<name>.py < input`).

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# **Notice:** sort once, then binary-search each query for presence — `O((n+q) log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
q = int(parts[1])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 2]))
    i = i + 1
values = sorted(values)
output = ""
i = 0
while i < q:
    target = int(parts[n + i + 2])
    lo = 0
    hi = n - 1
    answer = "NO"
    while lo <= hi:
        mid = (lo + hi) // 2
        if values[mid] == target:
            answer = "YES"
            lo = hi + 1
        elif values[mid] < target:
            lo = mid + 1
        else:
            hi = mid - 1
    if i > 0:
        output = output + "\n"
    output = output + answer
    i = i + 1
print(output)

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# **Notice:** sort once; `upper_bound - lower_bound` counts occurrences per query — `O((n+q) log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
q = int(parts[1])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 2]))
    i = i + 1
values = sorted(values)

def lower_bound(target):
    lo = 0
    hi = n
    while lo < hi:
        mid = (lo + hi) // 2
        if values[mid] < target:
            lo = mid + 1
        else:
            hi = mid
    return lo

def upper_bound(target):
    lo = 0
    hi = n
    while lo < hi:
        mid = (lo + hi) // 2
        if values[mid] <= target:
            lo = mid + 1
        else:
            hi = mid
    return lo

output = ""
i = 0
while i < q:
    target = int(parts[n + i + 2])
    count = upper_bound(target) - lower_bound(target)
    if i > 0:
        output = output + "\n"
    output = output + str(count)
    i = i + 1
print(output)

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# **Notice:** sort once; `lower_bound` gives each query's insertion position — `O((n+q) log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
q = int(parts[1])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 2]))
    i = i + 1
values = sorted(values)
output = ""
i = 0
while i < q:
    target = int(parts[n + i + 2])
    lo = 0
    hi = n
    while lo < hi:
        mid = (lo + hi) // 2
        if values[mid] < target:
            lo = mid + 1
        else:
            hi = mid
    if i > 0:
        output = output + "\n"
    output = output + str(lo)
    i = i + 1
print(output)

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# **Notice:** sort, then for each value binary-search its complement — `O(n log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
target = int(parts[1])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 2]))
    i = i + 1
values = sorted(values)
answer = "NO"
i = 0
while i < n - 1 and answer == "NO":
    complement = target - values[i]
    lo = i + 1
    hi = n - 1
    while lo <= hi:
        mid = (lo + hi) // 2
        if values[mid] == complement:
            answer = "YES"
            lo = hi + 1
        elif values[mid] < complement:
            lo = mid + 1
        else:
            hi = mid - 1
    i = i + 1
print(answer)

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# **Notice:** sort, then the smallest adjacent gap — `O(n log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 1]))
    i = i + 1
values = sorted(values)
best = abs(values[1] - values[0])
i = 2
while i < n:
    gap = values[i] - values[i - 1]
    if gap < best:
        best = gap
    i = i + 1
print(str(best))

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# **Notice:** complete search over every triple — `O(n^3)`, affordable only for small N.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
target = int(parts[1])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 2]))
    i = i + 1
answer = "NO"
i = 0
while i < n - 2 and answer == "NO":
    j = i + 1
    while j < n - 1 and answer == "NO":
        k = j + 1
        while k < n and answer == "NO":
            if values[i] + values[j] + values[k] == target:
                answer = "YES"
            k = k + 1
        j = j + 1
    i = i + 1
print(answer)

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# **Notice:** binary-search the answer (capacity) with a day-count feasibility check — `O(n log(sum))`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
allowed_days = int(parts[1])
weights = []
i = 0
while i < n:
    weights.append(int(parts[i + 2]))
    i = i + 1
lo = max(weights)
hi = sum(weights)
while lo < hi:
    mid = (lo + hi) // 2
    days = 1
    load = 0
    i = 0
    while i < n:
        if load + weights[i] > mid:
            days = days + 1
            load = weights[i]
        else:
            load = load + weights[i]
        i = i + 1
    if days <= allowed_days:
        hi = mid
    else:
        lo = mid + 1
print(str(lo))

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# **Notice:** sort; `upper_bound - lower_bound` counts values inside each `[lo, hi]` range — `O((n+q) log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
q = int(parts[1])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 2]))
    i = i + 1
values = sorted(values)

def lower_bound(target):
    lo = 0
    hi = n
    while lo < hi:
        mid = (lo + hi) // 2
        if values[mid] < target:
            lo = mid + 1
        else:
            hi = mid
    return lo

def upper_bound(target):
    lo = 0
    hi = n
    while lo < hi:
        mid = (lo + hi) // 2
        if values[mid] <= target:
            lo = mid + 1
        else:
            hi = mid
    return lo

output = ""
i = 0
while i < q:
    left = int(parts[n + i * 2 + 2])
    right = int(parts[n + i * 2 + 3])
    count = upper_bound(right) - lower_bound(left)
    if i > 0:
        output = output + "\n"
    output = output + str(count)
    i = i + 1
print(output)

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# **Notice:** complete search over all digit triples 0-9 — `O(1000)` (a constant).

# %%
import sys

data = sys.stdin.read()
parts = data.split()
target_sum = int(parts[0])
target_product = int(parts[1])
answer = "NONE"
first = 1
while first <= 9 and answer == "NONE":
    second = 0
    while second <= 9 and answer == "NONE":
        third = 0
        while third <= 9 and answer == "NONE":
            digit_sum = first + second + third
            digit_product = first * second * third
            if digit_sum == target_sum and digit_product == target_product:
                answer = str(first * 100 + second * 10 + third)
            third = third + 1
        second = second + 1
    first = first + 1
print(answer)
