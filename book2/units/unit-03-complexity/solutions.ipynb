# %% [markdown]
# # Unit 3 — Complexity Solutions
#
# Reference solutions for all nine exercises. Each is a runnable stdin program in `assets/<name>.py` (run it with `python assets/<name>.py < input`).

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# **Notice:** count scores at least the target in one pass — `O(n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
target = int(parts[1])
qualifying = 0
i = 0
while i < n:
    score = int(parts[i + 2])
    if score >= target:
        qualifying = qualifying + 1
    i = i + 1
print(str(qualifying))

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# **Notice:** running total; report the first turn index that reaches the goal — `O(n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
goal = int(parts[1])
total = 0
answer = -1
i = 0
while i < n:
    total = total + int(parts[i + 2])
    if answer == -1 and total >= goal:
        answer = i + 1
    i = i + 1
print(str(answer))

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# **Notice:** track the current and best streak in one pass — `O(n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
target = int(parts[1])
current = 0
best = 0
i = 0
while i < n:
    score = int(parts[i + 2])
    if score >= target:
        current = current + 1
        if current > best:
            best = current
    else:
        current = 0
    i = i + 1
print(str(best))

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# **Notice:** a frequency dictionary; most frequent, ties going to the smaller value — `O(n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
frequencies = {}
best_value = int(parts[1])
best_frequency = 0
i = 0
while i < n:
    value = int(parts[i + 1])
    frequencies[value] = frequencies.get(value, 0) + 1
    frequency = frequencies[value]
    if frequency > best_frequency or frequency == best_frequency and value < best_value:
        best_value = value
        best_frequency = frequency
    i = i + 1
print(str(best_value))

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# **Notice:** pair-sum via a `seen` dictionary of complements in one pass — `O(n)`, not the slow pair scan.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
target = int(parts[1])
seen = {}
found = False
i = 0
while i < n:
    value = int(parts[i + 2])
    needed = target - value
    if seen.get(needed, 0) > 0:
        found = True
    seen[value] = seen.get(value, 0) + 1
    i = i + 1
answer = "NO"
if found:
    answer = "YES"
print(answer)

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# **Notice:** sort once, then scan adjacent gaps for the smallest — `O(n log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
values = []
i = 0
while i < n:
    values.append(int(parts[i + 1]))
    i = i + 1
values.sort()
best = values[1] - values[0]
i = 2
while i < n:
    gap = values[i] - values[i - 1]
    if gap < best:
        best = gap
    i = i + 1
print(str(best))

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# **Notice:** a `seen` dictionary; the first value that repeats — `O(n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
seen = {}
answer = -1
i = 0
while i < n:
    value = int(parts[i + 1])
    if answer == -1 and seen.get(value, 0) > 0:
        answer = value
    seen[value] = 1
    i = i + 1
print(str(answer))

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# **Notice:** sort once, then the largest adjacent gap that is within the limit — `O(n log n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
limit = int(parts[1])
positions = []
i = 0
while i < n:
    positions.append(int(parts[i + 2]))
    i = i + 1
positions.sort()
best = -1
i = 1
while i < n:
    gap = positions[i] - positions[i - 1]
    if gap <= limit and gap > best:
        best = gap
    i = i + 1
print(str(best))

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# **Notice:** maximum-subarray running best (Kadane-style) in one pass — `O(n)`.

# %%
import sys

data = sys.stdin.read()
parts = data.split()
n = int(parts[0])
first = int(parts[1])
current = first
best = first
i = 1
while i < n:
    value = int(parts[i + 1])
    if current + value < value:
        current = value
    else:
        current = current + value
    if current > best:
        best = current
    i = i + 1
print(str(best))
