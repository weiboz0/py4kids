# %% [markdown]
# # Book 2 Checkpoint 3 — Mock Contest 3
#
# You have about **40–50 minutes** to solve seven problems. Each problem reads the whole contest input from standard input and prints the exact output. Read the input in your program with:
#
# ```python
# import sys
# data = sys.stdin.read()
# ```
#
# Write each answer as a complete program in the empty code cell below its question, and run it with piped input, for example `python my_solution.py < case.txt`. Do not call `input()`.
#
# Points for each question are listed in the points table in the teacher grading guide.

# %% [markdown]
# ## Question 1
#
# ### Spaced Permutation Count
#
# The first line is `N`, and the second line contains `N` distinct integers. Print the number of arrangements that use every given integer exactly once and have no two adjacent values whose difference has absolute value exactly `1`. Use recursive backtracking with a boolean list that marks a value before the recursive call and un-marks it after that call comes back. In the sample, four of the six possible arrangements put `1` next to `2`, while the final value can separate them in the two valid arrangements.
#
# ### Constraints
#
# `1 <= N <= 9`.
# Every given integer is distinct and is between `-1000000000` and `1000000000`.
#
# ### Sample Input
#
# ```text
# 3
# 1 2 4
# ```
#
# ### Sample Output
#
# ```text
# 2
# ```

# %% [markdown]
# ## Question 2
#
# ### Postfix Score
#
# The input is one valid space-separated postfix expression whose tokens are integers or the operators `+`, `-`, and `*`. Evaluate the expression from left to right using a `deque` as a stack: push with `appendleft`, and for an operator remove the right operand first and the left operand second with `popleft`. Print the final integer result. In the sample, subtraction order determines the intermediate value, and the final `+` changes the result from `10` to `17`.
#
# ### Constraints
#
# The expression contains between `1` and `200000` tokens and is guaranteed to be valid.
# Every integer token is between `-1000000000` and `1000000000`, and every intermediate result fits in a Python integer.
#
# ### Sample Input
#
# ```text
# 8 3 - 2 * 7 +
# ```
#
# ### Sample Output
#
# ```text
# 17
# ```

# %% [markdown]
# ## Question 3
#
# ### Decimal to Binary
#
# The input is one non-negative decimal integer `n`. Print its base-2 representation as a string with no `0b` prefix, computing the digits by hand with repeated remainder and integer-division operations rather than a built-in conversion; print `0` when `n` is `0`. In the sample, the final binary digit is `1` because the input is odd.
#
# ### Constraints
#
# `0 <= n <= 1000000000`.
#
# ### Sample Input
#
# ```text
# 13
# ```
#
# ### Sample Output
#
# ```text
# 1101
# ```

# %% [markdown]
# ## Question 4
#
# ### Exact-Total Subsets
#
# The first line contains `N T`, and the second line contains `N` positive integer weights. Print the number of subsets whose weights sum to exactly `T`, including the empty subset when `T` is `0`. Examine every subset as a bitmask from `0` through `(1 << N) - 1`, and test whether weight `i` belongs to a subset with `mask & (1 << i)`. In the sample, the unique matching subset uses the middle weights `3` and `7` together with the final weight `63`.
#
# ### Constraints
#
# `1 <= N <= 18`.
# Every weight is between `1` and `1000000000`, and `0 <= T <= 1000000000000000000`.
#
# ### Sample Input
#
# ```text
# 6 73
# 1 3 7 15 31 63
# ```
#
# ### Sample Output
#
# ```text
# 1
# ```

# %% [markdown]
# ## Question 5
#
# ### GCD and LCM
#
# The first line is `N`, and the second line contains `N` positive integers. Print two space-separated integers: the greatest common divisor of all the values followed by their least common multiple. Compute each GCD with Euclid's algorithm and combine the LCM one value at a time. In the sample, the final value keeps the overall GCD at `6` and raises the overall LCM from `72` to `360`.
#
# ### Constraints
#
# `1 <= N <= 100000`.
# Every input value is between `1` and `1000000000`, and the overall LCM is at most `1000000000000000000`.
#
# ### Sample Input
#
# ```text
# 4
# 12 18 24 30
# ```
#
# ### Sample Output
#
# ```text
# 6 360
# ```

# %% [markdown]
# ## Question 6
#
# ### Primes Up To N
#
# The input is one integer `N`. Print the number of prime integers `p` with `2 <= p <= N` by using a Sieve of Eratosthenes and crossing off multiples of each prime beginning at `p * p`. In the sample, `N` is `7 * 7`, so crossing off through that square boundary is necessary.
#
# ### Constraints
#
# `2 <= N <= 2000000`.
#
# ### Sample Input
#
# ```text
# 49
# ```
#
# ### Sample Output
#
# ```text
# 15
# ```

# %% [markdown]
# ## Question 7
#
# ### Pre-order Readout
#
# The first line contains `N root`, followed by `N` lines in node-index order from `0` through `N - 1`; each node line contains `value left right`, where `value` is the node's integer value and each child is a node index or `-1` when that child is missing. Print the node values in pre-order (root, then left subtree, then right subtree), separated by single spaces, using a recursive traversal over the stored node information. In the sample, root `2` has no right child, and the final pre-order value makes the traversal `40 10 30 20` instead of the values' sorted order.
#
# ### Constraints
#
# `1 <= N <= 100000`.
# Every node value is between `-1000000000` and `1000000000`; the root and non-missing child indices are between `0` and `N - 1`.
# The input describes one valid binary tree containing every node exactly once, and its height is at most `900`.
#
# ### Sample Input
#
# ```text
# 4 2
# 10 1 3
# 30 -1 -1
# 40 0 -1
# 20 -1 -1
# ```
#
# ### Sample Output
#
# ```text
# 40 10 30 20
# ```
