# %% [markdown]
# # Checkpoint 4 — Mock Contest 4 (Term 4 Finale)
#
# Timed mock contest covering Term 4 (grids, graphs, BFS/DFS, two pointers / sliding window) plus a modular-power problem. Each problem reads the whole contest input from standard input and prints the exact output. Read the input in your program with:
#
# ```python
# import sys
# data = sys.stdin.read()
# ```
#
# Write each answer as a complete program in the empty code cell below its question, and run it with piped input, for example `python my_solution.py < case.txt`. Do not call `input()`.

# %% [markdown]
# ## Question 1
#
# ### Count the Islands
#
# A grid of land (`#`) and water (`.`). Two land cells belong to the same island if they are next to each
# other up, down, left, or right (NOT diagonally). Count the islands.
#
# The program reads the whole input from standard input. First line: `R C`. Then `R` rows of the grid.
# Print the number of islands as an integer string.
#
# **Constraints:** `1 <= R`, `1 <= C`, `R*C <= 400`.
#
# **Sample Input**
#
# ```text
# 3 4
# #.#.
# ##..
# ...#
# ```
#
# **Sample Output**
#
# ```text
# 3
# ```

# %% [markdown]
# ## Question 2
#
# ### Fewest Steps
#
# A grid with one start `S`, one target `T`, walls `#`, and open cells `.`. From a cell you may step up,
# down, left, or right into an open cell (or `T`). Print the fewest steps from `S` to `T`, or `-1` if `T`
# cannot be reached.
#
# First line: `R C`. Then `R` rows. Print the step count (or `-1`) as an integer string.
#
# **Constraints:** `1 <= R`, `1 <= C`, `R*C <= 2000`.
#
# **Sample Input**
#
# ```text
# 2 3
# S#T
# ...
# ```
#
# **Sample Output**
#
# ```text
# 4
# ```

# %% [markdown]
# ## Question 3
#
# ### One Network?
#
# An undirected graph on nodes `1..N` with `M` edges. Is every node reachable from node `1` (is the whole
# graph one connected network)?
#
# First line: `N M`. Then `M` lines, each `u v` (an undirected edge between `u` and `v`). Print `YES` if
# the graph is one connected network, otherwise `NO`.
#
# **Constraints:** `1 <= N <= 300`, `0 <= M <= 2000`.
#
# **Sample Input**
#
# ```text
# 3 2
# 1 2
# 2 3
# ```
#
# **Sample Output**
#
# ```text
# YES
# ```

# %% [markdown]
# ## Question 4
#
# ### Exact Budget Pair
#
# Given `N` item prices and a target `T`, is there a pair of two *different* items whose prices add up to
# exactly `T`?
#
# First line: `N T`. Then `N` non-negative integer prices (they may span several lines). Print `YES` if some
# two distinct items sum to exactly `T`, otherwise `NO`.
#
# **Constraints:** `2 <= N <= 100000`, prices are non-negative integers.
#
# **Sample Input**
#
# ```text
# 4 10
# 1 8 3 7
# ```
#
# **Sample Output**
#
# ```text
# YES
# ```

# %% [markdown]
# ## Question 5
#
# ### Longest Affordable Streak
#
# Given `N` daily costs and a budget `K`, find the length of the LONGEST run of consecutive days whose total
# cost is at most `K`.
#
# First line: `N K`. Then `N` non-negative integer costs. Print the longest length (0 if no single day is
# affordable) as an integer string.
#
# **Constraints:** `1 <= N <= 100000`, `0 <= K`, costs are non-negative integers.
#
# **Sample Input**
#
# ```text
# 5 7
# 2 3 1 2 4
# ```
#
# **Sample Output**
#
# ```text
# 3
# ```

# %% [markdown]
# ## Question 6
#
# ### Astronomical Power Modulo M
#
# Given a base `A`, a modulus `M`, and an exponent `E`, print `A` to the power `E`, modulo `M`.
#
# Use repeated squaring and reduce modulo `M` after every multiplication and every squaring; computing the
# unreduced power first is infeasible for the enormous exponent. **Do not use a built-in modular-power
# shortcut** (no three-argument `pow`). Your algorithm must use O(log E) modular multiplications.
#
# Input: `A M E` on one line. Print the result (between `0` and `M - 1`) as an integer string.
#
# **Constraints:** `0 <= A <= 10^18`, `1 <= M <= 10^18`, `0 <= E <= 10^18`.
#
# **Sample Input**
#
# ```text
# 7 13 1000000000000000000
# ```
#
# **Sample Output**
#
# ```text
# 9
# ```

# %% [markdown]
# ## Question 7
#
# ### Trace the Traversal
#
# Trace this exact breadth-first routine and predict what it prints. Neighbours are visited in the order the
# edges are given.
#
# ```text
# seed visited with the single start node          # visited = {start}
# put start on the back of a FIFO queue
# while the queue is not empty:
#     take a node u from the FRONT of the queue
#     print u
#     for each out-neighbour v of u, in input order:
#         if v is not visited:
#             mark v visited and put it on the BACK of the queue
# ```
#
# Input first line: `N M start` (nodes `1..N`, `M` directed edges, and the BFS start node). Then `M` lines,
# each `u v`, a directed edge `u -> v`; a node's out-neighbours are in input order. Print the printed node
# ids in the order the routine prints them, space-separated.
#
# **Constraints:** `1 <= N <= 30`, `0 <= M <= 200`.
#
# **Sample Input**
#
# ```text
# 3 2 1
# 1 2
# 1 3
# ```
#
# **Sample Output**
#
# ```text
# 1 2 3
# ```
