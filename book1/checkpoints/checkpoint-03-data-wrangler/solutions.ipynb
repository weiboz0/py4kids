# %% [markdown]
# ## Question 1

# %%
word = "wizardry"
print(f"{word[0]} {word[-1]} {word[2:5]} {word[::-1]}")
assert word[::-1] == "yrdraziw"

# %% [markdown]
# ## Question 2

# %%
phrase = "  Hello, Data World!  "
cleaned = phrase.strip().lower().replace(",", "")
print("data" in cleaned)
assert cleaned == "hello data world!"

# %% [markdown]
# ## Question 3

# %%
scores = [88, 92, 75]
scores.append(100)
print(scores[0])
print(scores[-1])
assert len(scores) == 4
assert scores[0] == 88 and scores[-1] == 100

# %% [markdown]
# ## Question 4

# %%
scores = [88, 92, 75, 100]
for score in scores:
    print(score)
print(len(scores))
print(max(scores))
print(min(scores))
total = 0
for score in scores:
    total = total + score
print(total)
assert total == 355

# %% [markdown]
# ## Question 5

# %%
scores = [88, 92, 75, 100]
scores.sort(reverse=True)
print(scores[0])
print(scores[1])
print(scores[2])
assert scores[0] == 100

# %% [markdown]
# ## Question 6

# %%
prices = {"apple": 3, "pear": 2}
print(prices["pear"])
print(prices.get("fig", 0))
print("apple" in prices)
if "plum" in prices:
    branch_taken = "plum"
    print(prices["plum"])
elif "pear" in prices:
    branch_taken = "pear"
    print(prices["pear"])
else:
    branch_taken = "sold out"
    print("sold out")
assert prices.get("fig", 0) == 0
assert branch_taken == "pear"

# %% [markdown]
# ## Question 7

# %%
words = ["cat", "dog", "cat", "bird", "cat"]
counts = {}
for word in words:
    if word in counts:
        counts[word] = counts[word] + 1
    else:
        counts[word] = 1
for word, count in counts.items():
    print(word, count)
assert counts["cat"] == 3

# %% [markdown]
# ## Question 8
#
# The traceback names a `KeyError` and identifies `fig` as the missing key.

# %%
# Error name: KeyError; missing key: fig
prices = {"apple": 3}
fig_price = prices.get("fig", 0)
print(fig_price)
assert fig_price == 0
