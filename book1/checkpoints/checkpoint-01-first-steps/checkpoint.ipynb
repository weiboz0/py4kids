# %% [markdown]
# **Checkpoint 1 — First Steps**
#
# This is your chance to show what you've got from Story Machine and Number Detective. There are no trick questions. Read each one carefully, try your best, and leave a note when you want to explain your thinking.

# %% [markdown]
# ## Question 1
#
# A programmer runs this code and gets an error message. The broken code is shown as text, so do not try to run it yet.
#
# ```python
# clues_found = 4
# print("Clues found: " + clues_found)
# ```
#
# The last line of the traceback says:
#
# ```text
# TypeError: can only concatenate str (not "int") to str
# ```
#
# Read that message from the bottom up. What two types is Python being asked to join? Write a corrected `print` line that uses an f-string.

# %% [markdown]
# ## Question 2
#
# Predict exactly what this program prints. Work out the arithmetic before you run anything.
#
# ```python
# stars = 8
# bonus = 3
# total = stars + bonus * 2
# print(f"Detective score: {total}")
# ```
#
# Write the complete output, including the words and number.

# %% [markdown]
# ## Question 3
#
# Write **one line** of Python that asks `How many clues? `, converts the typed answer to an integer, and stores it in a variable named `clue_count`.

# %% [markdown]
# ## Question 4
#
# Trace this `if`/`elif`/`else` chain. Which one message prints, and why are the other two skipped?
#
# ```python
# secret = 20
# guess = 27
#
# if guess < secret:
#     print("Too low")
# elif guess > secret:
#     print("Too high")
# else:
#     print("Correct")
# ```

# %% [markdown]
# ## Question 5
#
# Complete only the condition after `while`. The loop should keep asking while the guess is different from the hard-coded secret. Do not add a counter.
#
# ```python
# secret = 7
# guess = int(input("Guess: "))
#
# while __________:
#     guess = int(input("Guess again: "))
#
# print("You found it!")
# ```
#
# Write the missing condition, not the whole program.

# %% [markdown]
# ## Question 6
#
# Two programmers store the same thing. Which name makes the program easier to understand: `x` or `player_guess`? Explain your choice in one sentence.
#
# Then write a useful comment for this line. Your comment should explain **why** the value matters instead of repeating the code.
#
# ```python
# secret = 42
# ```

# %% [markdown]
# ## Question 7
#
# Build a one-guess detective. Keep the hard-coded secret value in the starter. Ask for one integer guess, then use `if`, `elif`, and `else` to print exactly one clue: `Too low!`, `Too high!`, or `Case closed!`.

# %%
secret = 8
guess = int(input("Your one guess: "))

# Write your if/elif/else chain below.
