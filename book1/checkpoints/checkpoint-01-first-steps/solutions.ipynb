# %% [markdown]
# # Checkpoint 1 — First Steps Solutions

# %% [markdown]
# The `assert` lines are CI self-checks that students can ignore. Any `random.seed(4)` calls would also be CI self-checks that students can ignore.

# %% [markdown]
# ## Question 1
#
# Python was asked to join a string and an integer. Converting the integer with `str(...)` makes working `+` string concatenation possible.

# %%
clues_found = 4
clue_message = "Clues found: " + str(clues_found)
print(clue_message)
assert clue_message == "Clues found: 4"

# %% [markdown]
# *Debug question (read the traceback) — fixed data on purpose, no `input()` version.*

# %% [markdown]
# ## Question 2
#
# The complete output is `Detective score: 14`.

# %%
stars = 8
bonus = 3
total = stars + bonus * 2
print(f"Detective score: {total}")
assert total == 14

# %% [markdown]
# *Predict-the-output question — fixed data on purpose, no `input()` version.*

# %% [markdown]
# ## Question 3
#
# The answer line is `clue_count = int(input("How many clues? "))` — `input(...)` reads text, `int(...)` turns it into a number.

# %%
# Headless self-check: a typed value stands in for the real reply.
clue_count = int("6")
assert clue_count == 6

# %% [markdown]
# **The real program** (the one line that reads the count):
#
# ```python
# clue_count = int(input("How many clues? "))
# ```

# %% [markdown]
# ## Question 4

# %%
secret = 20
guess = 27
if guess < secret:
    result = "Too low"
elif guess > secret:
    result = "Too high"
else:
    result = "Correct"
print(result)
# Why 'Too high' prints: Python checks top to bottom. guess < secret (27 < 20) is
# False, so that branch is skipped. guess > secret (27 > 20) is True, so 'Too high'
# runs; once one branch runs, the remaining elif/else are not checked at all.
assert result == "Too high"

# %% [markdown]
# *Trace question — fixed data on purpose, no `input()` version.*

# %% [markdown]
# ## Question 5
#
# The missing condition is `guess != secret`.

# %%
secret = 7
guess = 3  # Sample stand-in guess.
keep_guessing = guess != secret
print(keep_guessing)
assert guess != secret
assert keep_guessing is True

# %% [markdown]
# **The real program** (the completed guess loop — the missing condition is `guess != secret`):
#
# ```python
# secret = 7
# guess = int(input("Guess: "))
# while guess != secret:
#     guess = int(input("Guess again: "))
# print("You found it!")
# ```

# %% [markdown]
# ## Question 6
#
# `player_guess` is easier to understand because its name tells us what value the variable stores.

# %%
# This is the answer the player's guess must match to solve the case.
secret = 42

# %% [markdown]
# *Naming/comment concept question — no `input()` version.*

# %% [markdown]
# ## Question 7

# %%
secret = 8
guess = 10  # Sample stand-in value for the player's one guess.

if guess < secret:
    clue = "Too low!"
elif guess > secret:
    clue = "Too high!"
else:
    clue = "Case closed!"

print(clue)
assert clue == "Too high!"

# %% [markdown]
# **The real program** (reads the player's one guess):
#
# ```python
# secret = 8
# guess = int(input("Your one guess: "))
# if guess < secret:
#     clue = "Too low!"
# elif guess > secret:
#     clue = "Too high!"
# else:
#     clue = "Case closed!"
# print(clue)
# ```
