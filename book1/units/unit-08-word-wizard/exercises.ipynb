# %% [markdown]
# # Word Wizard Exercises
#
# Your WORD WIZARD needs a bigger phrasebook and a sharper spell-checker. Teach it to translate safely, tidy messy searches, and count the words in a growing log. Write your work in each blank code cell.

# %% [markdown]
# ## Exercise 1: Build a Phrasebook
#
# Build a dictionary named `translations` with these three English-to-Spanish pairs: `"sun"` maps to `"sol"`, `"moon"` maps to `"luna"`, and `"star"` maps to `"estrella"`. Use one dictionary literal, then print the dictionary.

# %% [markdown]
# ## Exercise 2: Safe Lookup
#
# A full Word Wizard game might ask the player for a word with `input("Word? ")`, but **do not call `input()` in your code cell**. Instead, use `translations = {"cat": "gato", "dog": "perro"}` and the fixed sample variable `word = "fish"`. Look up `word` with `.get(word, "???")`, store the result, and print it.

# %% [markdown]
# ## Exercise 3: Is It in the Book?
#
# Start with `translations = {"cat": "gato", "dog": "perro"}` and `word = "cat"`. Use `if word in translations` as a condition. Print a friendly message when the word is known and a different friendly message otherwise. Test again with `word = "fish"`.

# %% [markdown]
# ## Exercise 4: Add a Word
#
# Start with `translations = {"cat": "gato"}`. Add the key `"bird"` with the value `"pajaro"` by assigning through square brackets. Print the grown phrasebook, then print the translation stored at `"bird"`.

# %% [markdown]
# ## Exercise 5: Count the Words
#
# Use the given log `words = ["owl", "fox", "owl", "cat", "owl"]` and start with `counts = {}`. Use a **single loop** over `words`. If a word is already in `counts`, add 1 to its count; otherwise, give its first sighting the count 1. Print `counts` after the loop.

# %% [markdown]
# ## Exercise 6: Most Common Word
#
# Start with `counts = {"owl": 3, "fox": 1, "cat": 1}`, `best_word = ""`, and `best_count = 0`. Use a **single loop** over `counts.items()`. Whenever a count is greater than `best_count`, save both the new count and its word. Print the most common word and its count after the loop.

# %% [markdown]
# ## Exercise 7: Grow the Log
#
# Start with `words = ["cat", "dog", "cat"]` and `new_word = "cat"`. Append `new_word` to `words`. Then **reset** with `counts = {}` and use a single loop to count the entire grown list from scratch. Print the new dictionary. Resetting keeps the old words from being counted twice.

# %% [markdown]
# ## Exercise 8: Tidy, Then Translate
#
# Use `translations = {"cat": "gato", "dog": "perro"}` and `raw_word = "  CAT "`. Build a clean word with `.strip().lower()`, then use the clean word to look up and print `"gato"`.

# %% [markdown]
# ## Exercise 9: Print Every Pair
#
# Start with `translations = {"hello": "hola", "cat": "gato", "dog": "perro"}`. Use one loop over `translations.items()` to receive each word and translation together. Print every pair in a friendly f-string.

# %% [markdown]
# ## Exercise 10: Translate a List
#
# Define `translate(word, dictionary)` so it returns `dictionary.get(word, "???")`. Use `translations = {"hello": "hola", "cat": "gato"}` and the given list `words = ["cat", "hello", "fish"]`. Loop over `words` and print each word's translation by calling `translate` inside the loop.

# %% [markdown]
# ## Exercise 11: Fix the KeyError
#
# This lookup crashes because the phrasebook does not contain `"fish"`:
#
# ```python
# translations = {"cat": "gato"}
# print(translations["fish"])
# ```
#
# Write the phrasebook in your code cell, then replace the crashing square-bracket lookup with `.get("fish", "???")`. Print the safe result.

# %% [markdown]
# ## Challenge 1: Reverse Lookup
#
# The wizard knows a Spanish word and wants to find its English key. Use `translations = {"cat": "gato", "dog": "perro", "bird": "pajaro"}`, `target = "perro"`, and `english_word = "???"`. Use a **single loop** over `translations.items()`. When a translation equals `target`, save its key in `english_word`. Print `english_word` after the loop.

# %% [markdown]
# ## Challenge 2: Merge Two Phrasebooks
#
# Start with `translations = {"cat": "gato", "dog": "perro"}` and `new_translations = {"bird": "pajaro", "fish": "pez"}`. Use a **single loop** over `new_translations.items()`. Copy each pair into `translations` with `translations[word] = translation`. Print the grown phrasebook after the loop.
