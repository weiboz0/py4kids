# %% [markdown]
# # Story Machine Practice
#
# Make each program your own. Run your work often. When something breaks, read the final traceback line for a clue.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Greeting-card printer
#
# Print a title and a friendly message for someone. Use a separate `print()` instruction for each part. Add a comment that explains what your program makes.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Fix the missing quote
#
# Run the broken snippet only when you are ready to read its error message. Find the line named at the end of the traceback. Fix the quote so the greeting can print.

# %%
print("Welcome to the marshmallow castle!)

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Fix the mixed-up name
#
# This program stops because a variable name changes spelling. Read the final traceback line. Make the names match, then remix the saved string.

# %%
favorite_snack = "popcorn"
print(f"The dragon wants {favourite_snack}.")

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Story remix with variables
#
# Save a hero, a place, and a silly object in clearly named variables. Print a short story that reuses every variable. Use an f-string for part of the story.

# %%
hero = "your hero"
place = "your place"
silly_object = "your silly object"

# Add your story below.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Interview bot
#
# Ask the player for a name, a favorite snack, and a dream job. Save each reply in a clear variable. Use the replies in a cheerful f-string message.

# %%
name = input("What is your name? ")

# Add the other prompts and the cheerful message.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ### Story Machine remix
#
# Create a new Mad-Libs story. Collect a character, a place, an object, and an action with `input()`. Save each reply in a clear variable. Print a title with string concatenation. Print the story with f-strings. Add a comment that describes your remix.

# %%
# Collect your story ingredients.
character = input("Name a character: ")

# Keep building your Story Machine.

# %% [markdown]
# ## Challenge
#
# Try these when your core exercises are ready.

# %% [markdown]
# ### Challenge 1
#
# Write a multi-paragraph story. Print an empty string literal between paragraphs to make a blank line. Reuse the same hero and place variables in every paragraph.

# %% [markdown]
# ### Challenge 2
#
# Build an emoji-art title generator. Ask for an emoji and title words with `input()`. Save both replies. Use string concatenation or an f-string to place the emoji around the title.
