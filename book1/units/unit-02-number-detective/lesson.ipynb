# %% [markdown]
# # Number Detective
#
# The computer picks a secret number. Can you find it in only a few guesses? By the end of this unit you will build the whole guessing game yourself.
#
# Each new idea comes as a short **ladder**: the simplest version, then one small twist, then a real use. The **Notice** line after each rung points at the single new thing.

# %% [markdown]
# ## L1: Numbers
#
# A whole number such as `7`, `0`, or `-12` is an **integer** — Python calls this the `int` type. No quotes are needed.

# %%
age = 11
print(age)

# %% [markdown]
# **Notice:** `11` is an integer — a whole number stored without quotes.

# %%
temperature = -4
score = 0
print(temperature)
print(score)

# %% [markdown]
# **Notice:** integers include negatives and zero, not just counting numbers.

# %%
clue = 7
label = "7"
print(clue)
print(label)

# %% [markdown]
# **Notice:** `7` is an integer; `"7"` is text that only looks like one — Python treats them differently (you will see how in a moment).

# %% [markdown]
# Integers can do **arithmetic**: add `+`, subtract `-`, multiply `*`. `//` tells how many whole groups fit, and `%` tells what is left over.

# %%
print(5 + 3)

# %% [markdown]
# **Notice:** Python works out the math and prints the result.

# %%
print(10 - 4)

# %% [markdown]
# **Notice:** `-` subtracts.

# %%
print(6 * 7)

# %% [markdown]
# **Notice:** `*` multiplies.

# %%
marbles = 12
found = 5
print(marbles + found)

# %% [markdown]
# **Notice:** arithmetic works on saved numbers, not only typed-in ones.

# %%
print(17 // 5)

# %% [markdown]
# **Notice:** `//` gives how many whole groups fit — `17 // 5` is `3`.

# %%
print(17 % 5)

# %% [markdown]
# **Notice:** `%` gives what is left over after those groups — `17 % 5` is `2`.

# %% [markdown]
# One catch: `input()` always gives **text**, even when someone types digits. Use `int()` to turn digit-text into an integer and `str()` to turn an integer back into text. This is **type conversion**.

# %%
typed = "27"
number = int(typed)
print(number)

# %% [markdown]
# **Notice:** `int("27")` becomes the number `27`, ready for arithmetic.

# %%
count = 5
count_text = str(count)
print(f"As text, the count is {count_text}.")

# %% [markdown]
# **Notice:** `str()` turns a number into text — the reverse of `int()`.

# %%
guess = int(input("Enter an integer: "))
print(f"You entered {guess}.")

# %% [markdown]
# **Notice:** wrap `input()` in `int()` whenever you need a number from the keyboard.

# %% [markdown]
# ## L2: The Computer Picks and Judges
#
# `import random` brings in Python's random-number tools. `random.randint(1, 100)` then picks an integer from 1 through 100 — both ends can be picked.

# %%
import random

# %% [markdown]
# **Notice:** `import random` loads Python's random toolbox — it prints nothing by itself, but the tools are now ready to use.

# %%
import random
print(random.randint(1, 6))

# %% [markdown]
# **Notice:** now `random.randint(1, 6)` rolls a number 1 through 6 (both ends can be picked).

# %%
import random
print(random.randint(1, 100))

# %% [markdown]
# **Notice:** change the two numbers to change the range.

# %%
import random
secret = random.randint(1, 10)
print(f"(teacher peek) the secret is {secret}")

# %% [markdown]
# **Notice:** save the pick in a variable to use later — this is how the game hides its secret.

# %% [markdown]
# Now the computer must judge a guess. A **comparison** asks a yes-or-no question; its answer is a **boolean**, `True` or `False`. Use `==` equal, `!=` not equal, `<` less than, `>` greater than.

# %%
print(7 == 7)

# %% [markdown]
# **Notice:** a comparison reports `True` or `False` — a boolean.

# %%
print(3 < 10)
print(10 < 3)

# %% [markdown]
# **Notice:** `<` is True only when the left side is smaller.

# %%
print(5 != 4)
print(5 != 5)

# %% [markdown]
# **Notice:** `!=` is "not equal" — True when the two values differ.

# %%
print(5 > 2)
print(2 > 5)

# %% [markdown]
# **Notice:** `>` is "greater than" — the mirror of `<`. Now you have all four: `==`, `!=`, `<`, `>`.

# %%
secret = 42
guess = 30
print(guess == secret)
print(guess < secret)

# %% [markdown]
# **Notice:** you can compare saved numbers — exactly what the game needs to judge a guess.

# %%
secret = 42
guess = 30
is_too_low = guess < secret
print(is_too_low)

# %% [markdown]
# **Notice:** the `True`/`False` answer can be saved in a variable and reused later.

# %% [markdown]
# ## L3: Make a Choice
#
# An **`if` statement** runs its indented lines only when a comparison is `True`.

# %%
guess = 30
secret = 42
if guess < secret:
    print("Too low!")

# %% [markdown]
# **Notice:** the indented `print` runs only because `30 < 42` is True.

# %%
guess = 50
secret = 42
if guess < secret:
    print("Too low!")
print("(done checking)")

# %% [markdown]
# **Notice:** when the `if` is False, Python skips the indented line and carries on.

# %%
guess = 30
secret = 42
if guess == secret:
    print("Found it!")
else:
    print("Keep trying.")

# %% [markdown]
# **Notice:** `else` runs when the `if` is False — exactly one of the two always runs.

# %% [markdown]
# **`elif`** adds more choices between `if` and `else`. Python checks them top to bottom and takes the first comparison that is `True`.

# %%
guess = 30
secret = 42
if guess > secret:
    print("Too high!")
elif guess < secret:
    print("Too low!")
else:
    print("Just right!")

# %% [markdown]
# **Notice:** `elif` is checked only when the tests above it were False.

# %%
temperature = 15
if temperature > 25:
    print("Hot")
elif temperature > 10:
    print("Warm")
else:
    print("Cold")

# %% [markdown]
# **Notice:** Python takes the FIRST branch whose test is True, then stops checking the rest.

# %%
secret = 37
guess = 52

if guess > secret:
    print("Too high!")
elif guess < secret:
    print("Too low!")
else:
    print("You found it!")

# %% [markdown]
# **Notice:** with a fixed secret and guess, the one-guess game runs here and gives the same kind of verdict as the real version below.

# %%
import random
secret = random.randint(1, 100)
guess = int(input("Your one guess: "))

if guess > secret:
    print("Too high!")
elif guess < secret:
    print("Too low!")
else:
    print("You found it!")

# %% [markdown]
# **Notice:** put it together and the detective gives a verdict for one real guess.

# %% [markdown]
# ## L4: The Full Game
#
# One guess is not much of a game. A **`while` loop** repeats its indented lines while a comparison stays `True`. Tally guesses **on paper** — do not add a guess-counting variable (the computer learns that trick in a later unit).

# %%
answer = input("Type the word stop to finish: ")
while answer != "stop":
    print("Not yet...")
    answer = input("Type the word stop to finish: ")
print("Stopped!")

# %% [markdown]
# **Notice:** the loop repeats while the test is True; typing `stop` makes it False and the loop ends.

# %%
secret = 7
guess = int(input("Guess the number: "))
while guess != secret:
    print("Nope, guess again.")
    guess = int(input("Guess again: "))
print("Correct!")

# %% [markdown]
# **Notice:** each trip asks again; when the guess matches the secret, the loop stops.

# %%
secret = 7
guess = int(input("Guess the number: "))
while guess != secret:
    if guess > secret:
        print("Too high!")
    else:
        print("Too low!")
    guess = int(input("Guess again: "))
print("Got it!")

# %% [markdown]
# **Notice:** put an `if` inside the loop to give a smarter hint on every guess.

# %%
secret = 37
guess = 50

while guess != secret:
    if guess > secret:
        print("Too high!")
    else:
        print("Too low!")
    guess = secret

print("Correct! Case closed.")

# %% [markdown]
# **Notice:** the fixed follow-up guess lets this full game run without typing; the real version below reads each guess from the player.

# %%
import random
secret = random.randint(1, 100)
guess = int(input("Guess the secret number: "))

while guess != secret:
    if guess > secret:
        print("Too high!")
    else:
        print("Too low!")
    guess = int(input("Guess again: "))

print("Correct! Case closed.")

# %% [markdown]
# **Notice:** the full detective game — `random` picks, `while` repeats, `if/else` hints.

# %% [markdown]
# Detectives inspect clues; programmers inspect error messages. The next snippet is intentionally broken. Run it, type `20`, and read the traceback from the bottom: what two types was it asked to compare?

# %%
# Intentionally broken: read the traceback to find the clue.
secret = 50
guess = input("Guess a number: ")

if guess < secret:
    print("Too low!")
else:
    print("Too high or correct!")

# %% [markdown]
# The traceback points to the comparison: `input()` made text, but `secret` is an integer. Convert the typed guess before comparing it.

# %%
# Fixed: both compared values are integers.
secret = 50
guess = int(input("Guess a number: "))

if guess < secret:
    print("Too low!")
else:
    print("Too high or correct!")

# %% [markdown]
# Play your full game with a partner. Mark one line on paper for every guess, then swap seats and play again.

# %% [markdown]
# ## Algorithm Extension
#
# *The **sentinel-loop** pattern Spotlight (repeat until a stop signal), gathered here for reference — read in class; its exercise is the last one in the exercises notebook.*

# %% [markdown]
# ### Pattern Spotlight: Repeat until done (sentinel loop)
# <!-- pattern: sentinel-loop -->
# You know when you're done; the program must ask "done yet?" every pass.
#
# **Computational-thinking contrast:** Unlike a loop that runs a fixed number of times, a sentinel loop repeats until its condition says the job is done.

# %%
guess = 3
secret = 7
print(guess != secret)

# %% [markdown]
# **Notice:** while the guess does NOT equal the secret, `guess != secret` is `True` — the loop keeps going.

# %%
guess = 7
secret = 7
print(guess != secret)

# %% [markdown]
# **Notice:** the moment the guess matches, `guess != secret` is `False` and the loop STOPS — that match is the sentinel.

# %%
guess = 1
secret = 7
while guess != secret:
    guess = secret
print(guess)

# %% [markdown]
# **Notice:** the `while` repeats as long as `guess != secret`; here one pass sets `guess` to the secret, the condition turns `False`, and the loop ends — the sentinel in action.

# %%
secret = 7
guess = 1
while guess != secret:
    guess = secret
print("Got it!")

# %% [markdown]
# **Notice:** the scripted follow-up reaches the sentinel and prints the same result line as the real input game below.

# %%
import random
secret = random.randint(1, 10)
guess = 0
while guess != secret:
    guess = int(input("Guess a number 1-10: "))
print("Got it!")

# %% [markdown]
# **Notice:** the real game — the loop repeats, reading a NEW guess each time, until the guess equals the secret (the sentinel that ends it). It uses `input()`, so this cell is display-only (not run here).
