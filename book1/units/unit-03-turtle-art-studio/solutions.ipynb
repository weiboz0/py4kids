# %% [markdown]
# # Turtle Art Studio Solutions
#
# This notebook keeps every answer headless. The runnable turtle drawings are in the named solution scripts.

# %% [markdown]
# ## Exercise 1
#
# The completed drawing answer is in `assets/solutions_l1.py`.

# %%
straight_sides = 4
side_length = 100
turn_angle = 90
ending_direction = "the starting direction"
print(f"Prediction: {straight_sides} sides, each {side_length} steps long.")
print(f"Every turn is {turn_angle} degrees.")
print(f"The turtle ends facing {ending_direction}.")
assert straight_sides == 4
assert side_length == 100
assert turn_angle == 90

# %% [markdown]
# ## Exercise 2
#
# Each range starts at 0 and stops before its ending number.

# %%
range_three_trips = 3
range_three_counters = "0, 1, 2"
range_five_trips = 5
range_five_counters = "0, 1, 2, 3, 4"
range_eight_trips = 8
range_eight_counters = "0, 1, 2, 3, 4, 5, 6, 7"
print(range_three_trips, range_three_counters)
print(range_five_trips, range_five_counters)
print(range_eight_trips, range_eight_counters)
print("The last value is one less because range stops before its ending number.")
assert range_eight_trips == 8
assert range_eight_counters == "0, 1, 2, 3, 4, 5, 6, 7"

# %% [markdown]
# ## Exercise 3
#
# The loop now takes one trip for each of the four sides.

# %%
side_count = 4

# range(4) repairs the plan by making four loop trips.
for side_number in range(4):
    side_length = 80
    turn_angle = 90

assert side_count == 4
assert side_number == 3

# %% [markdown]
# ## Exercise 4
#
# The matching nested-loop drawing is in `assets/solutions_l3.py`.

# %%
outer_loop_trips = 24
inner_loop_trips = 6
complete_design_sides = outer_loop_trips * inner_loop_trips
rotating_loop = "outer loop"
explanation = "The inner loop draws all six sides of one polygon before the outer loop rotates to begin another polygon."
print(outer_loop_trips, inner_loop_trips, complete_design_sides)
print(rotating_loop)
print(explanation)
assert complete_design_sides == 144

# %% [markdown]
# ## Exercise 5
#
# This pentagon plan is drawn by `assets/solutions_l2.py`.

# %%
# A five-sided regular pentagon.
n = 5
side_length = 90
angle = 360 / n
counter_values = "0, 1, 2, 3, 4"
print(f"n = {n}, side length = {side_length}, angle = {angle}")
print(counter_values)
assert angle == 72.0
assert counter_values == "0, 1, 2, 3, 4"

# %% [markdown]
# ## Exercise 6
#
# The repaired nested-loop idea is also demonstrated by `assets/solutions_l3.py`.

# %%
shape_count = 10
side_count = 4

for shape_number in range(10):  # The outer loop controls the 10 whole shapes.
    for side_number in range(4):  # The inner loop controls the 4 sides of one shape.
        side_length = 50
        turn_angle = 90
    turn_between_shapes = 36

assert shape_number == 9
assert side_number == 3

# %% [markdown]
# ## Challenge
#
# ### Challenge 1
#
# The star can be tried by changing the parameters in `assets/solutions_l2.py`.

# %%
# A five-point star.
n = 5
side_length = 120
angle = 720 / 5
counter_values = "0, 1, 2, 3, 4"
path_explanation = "The 144-degree turn skips across the middle instead of following a pentagon's edge."
print(n, side_length, angle)
print(counter_values)
print(path_explanation)
assert angle == 144.0

# %% [markdown]
# ### Challenge 2
#
# The runnable rainbow version is in `assets/solutions_l3.py`. These strings keep its six color-change commands headless here.

# %%
color_command_one = 'turtle.color("red")'
color_command_two = 'turtle.color("orange")'
color_command_three = 'turtle.color("yellow")'
color_command_four = 'turtle.color("green")'
color_command_five = 'turtle.color("blue")'
color_command_six = 'turtle.color("purple")'
color_order = "red, orange, yellow, green, blue, purple"
expected_pattern = "Four polygons of each color rotate into a 24-shape rainbow ring."
print(color_command_one)
print(color_command_two)
print(color_command_three)
print(color_command_four)
print(color_command_five)
print(color_command_six)
print(color_order)
print(expected_pattern)
assert color_order == "red, orange, yellow, green, blue, purple"
