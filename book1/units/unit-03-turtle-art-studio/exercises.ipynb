# %% [markdown]
# # Turtle Art Studio Exercises
#
# You will predict, trace, repair, and design turtle art. Keep every answer in this notebook. The drawing scripts stay in `assets/`.
#
# How to answer in words: put your sentence inside quotes in a variable, then print it —
# `answer = "The turtle draws a square."` then `print(answer)`.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Read `assets/l1_square.py` without running it. Predict the drawing. Record the number of straight sides, the length of each side, every turn angle, and the direction the turtle faces at the end. Then run the script from a terminal and compare the picture with your prediction.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Complete this `range()` prediction table. Write every counter value in order. Do the predictions without running turtle code.
#
# | Loop | Number of trips | Counter values |
# |---|---:|---|
# | `range(3)` | ___ | ___ |
# | `range(5)` | ___ | ___ |
# | `range(8)` | ___ | ___ |
#
# Explain why the last counter value is one less than the number inside `range()`.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# This headless plan is meant to stand for a four-sided drawing, but the loop makes the wrong number of sides. Change one number so the loop takes four trips. Keep the counter name. Add a comment that explains your repair.

# %%
side_count = 4

for side_number in range(3):
    side_length = 80
    turn_angle = 90

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Read the nested loops in `assets/l3_spirograph.py`. Complete the trace below before running the script.
#
# | Question | Your prediction |
# |---|---|
# | How many trips does the outer loop take? | ___ |
# | How many trips does the inner loop take during one outer trip? | ___ |
# | How many straight sides are drawn in the complete design? | ___ |
# | Which loop rotates between whole polygons? | ___ |
#
# Describe why the inner loop must finish before the next polygon begins.

# %% [markdown]
# ## Exercise 5
# When your plan is ready: open `assets/l2_polygons.py`, change `n` and `side_length` to your values, save, and run it in the terminal to confirm your prediction.

# %% [markdown]
# Design your own regular polygon for `assets/l2_polygons.py`. Choose `n` and `side_length`. Write the matching line `angle = 360 / n`. Predict the counter values from `range(n)`. Add a comment naming the shape you expect. Keep your work headless in the cell below.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# The plan below should make 10 four-sided shapes. Two loop numbers are wrong. Repair both numbers. Then write a comment beside the outer loop and a comment beside the inner loop. Each comment should say what that loop controls.

# %%
shape_count = 10
side_count = 4

for shape_number in range(8):
    for side_number in range(3):
        side_length = 50
        turn_angle = 90
    turn_between_shapes = 36

# %% [markdown]
# ## Challenge
#
# Try these after the six core exercises.

# %% [markdown]
# ### Challenge 1
#
# A five-point star uses five equal moves, but it turns farther than a regular five-sided polygon. Plan star parameters using `n = 5`, your own `side_length`, and `angle = 720 / 5`. Predict the counter values. Then explain how this larger turn angle changes the path. Keep the plan in the blank headless cell.

# %% [markdown]
# ### Challenge 2
#
# Plan a rainbow rosette (a ring of colored shapes) inspired by `assets/l3_spirograph.py`. Choose six literal color names. Write six separate color-change commands, one per line, such as `turtle.color("red")`. On paper, mark where each command belongs as the outer loop builds the picture. Describe the order of the colors and the pattern you expect. Do not run turtle code in this notebook.

# %% [markdown]
# Your rainbow plan:
#
# 1. ___
# 2. ___
# 3. ___
# 4. ___
# 5. ___
# 6. ___
#
# Expected pattern: ___
