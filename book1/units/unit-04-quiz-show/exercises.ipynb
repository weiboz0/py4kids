# %% [markdown]
# # Quiz Show Exercises
#
# Take over the host's desk. You will score answers, repair bonus rules, remix sudden death, and predict what the scoreboard will show.

# %% [markdown]
# ## Exercise 1
#
# ### Score the answers
#
# The three boolean variables tell whether each answer was correct. Add three separate `if` statements. Each true value should add 1 point with `score = score + 1`. Do not change the given answer values. Run the cell and inspect the scoreboard.

# %%
score = 0
answer_1_correct = True
answer_2_correct = False
answer_3_correct = True

# Add your three if statements here.

print(f"Score: {score}")

# %% [markdown]
# ## Exercise 2
#
# ### Fix the streak logic
#
# The bonus rule says: award 2 points only when the current answer is correct **and** the streak is alive. The code uses the wrong logical operator, so it can award an unfair bonus. Change exactly one word to repair the rule, then try other `True` and `False` combinations.

# %%
score = 3
answer_correct = False
streak_alive = True

# Broken on purpose: this operator does not match the bonus rule.
if answer_correct or streak_alive:
    score = score + 2

print(f"Score after the bonus check: {score}")

# %% [markdown]
# ## Exercise 3
#
# ### Add a category bonus
#
# Start with the values below. If `answer_correct` is true, add 1 point. Inside that `if`, add another `if` that awards 2 more points when `category == "science"`. The category bonus must stay locked when the answer is wrong.

# %%
score = 4
category = "science"
answer_correct = True

# Add the outer if and nested if here.

print(f"Score after the category question: {score}")

# %% [markdown]
# ## Exercise 4
#
# ### Sudden-death remix
#
# Create your own three-question sudden-death round. Use `questions_asked = 0` and a `while questions_asked < 3` loop. Inside it, use an `if`/`elif` chain keyed on counter values 0, 1, and 2 to ask exactly three hard-coded questions. Add 1 point after each correct answer. A wrong answer must print a dramatic message and use `break` to end the round.
#
# Write each question directly in its branch. Do not use lists, functions, or string methods.

# %% [markdown]
# ## Exercise 5
#
# ### Error-message debugging
#
# This host program is broken on purpose. Run it and type `3`. Read the traceback from the bottom and find the line Python points to. Explain the two types it tried to add, then repair the input line so the score calculation works.

# %%
# Broken on purpose: use the traceback as a clue.
score = 2
bonus = input("Bonus points: ")
score = score + bonus
print(f"New score: {score}")

# %% [markdown]
# ## Exercise 6
#
# ### Predict the score
#
# Cover the last `print` line. Trace the code on paper and predict the final score and the final value of `questions_asked`. Pay special attention to the streak bonus and the point where `break` runs. Then uncover the line and run the cell to check.

# %%
score = 0
streak_alive = True
first_correct = True
second_correct = True

if first_correct:
    score = score + 1
else:
    streak_alive = False

if second_correct:
    score = score + 1
else:
    streak_alive = False

if second_correct and streak_alive:
    score = score + 2

questions_asked = 0
while questions_asked < 3:
    if questions_asked == 0:
        correct = True
    elif questions_asked == 1:
        correct = False
    elif questions_asked == 2:
        correct = True

    questions_asked = questions_asked + 1
    if correct:
        score = score + 1
    else:
        break

print(f"Score: {score}; questions asked: {questions_asked}")

# %% [markdown]
# ## Exercise 7
#
# Some quiz shows punish coasting: if a player is **not** on a streak, a wrong answer costs them a point. Complete the rule using `not` so `penalty` is `True` only when the player is not on a streak **and** got the answer wrong.
#
# ```python
# on_streak = False
# answer_correct = False
# # penalty = ...
# print(penalty)
# ```

# %%
# Write your penalty rule here.

# %% [markdown]
# ## Challenge
#
# Try these after the six core exercises.

# %% [markdown]
# ### Challenge 1 — Double or Nothing
#
# Begin with `score = 4`. Ask whether the player wants to risk those points. Only if the player types `yes`, ask one hard-coded question. If that answer is correct, double the score with arithmetic. If it is wrong, set the score to 0. If the player does not type `yes`, keep the original score. Use nesting so the quiz question exists only inside the risk choice.

# %% [markdown]
# ### Challenge 2 — Lightning-Round Countdown
#
# Make a visible countdown from 5 to 1 with a `while` loop. Start with `seconds_left = 5`. Each trip should print the counter, then update it with `seconds_left = seconds_left - 1`. After the loop, print `Time!`. This uses the counter idea from Unit 03; it does not need a new kind of collection or helper.
