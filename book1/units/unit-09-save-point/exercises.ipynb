# %% [markdown]
# # SAVE POINT Exercises
#
# A game that forgets everything when you close it is no fun.
# In these missions, you will teach the program to **WRITE** progress to a file and **LOAD** it back next time.
# Keep integer scores in `savegame.txt` and text settings in `settings.txt`.

# %% [markdown]
# ## Exercise 1: Save a Score List — `savegame.txt`
#
# Start with `scores = [1200, 850, 990]`.
# Open `savegame.txt` with a `with` block in `"w"` mode.
# Loop over the list and write each score as text followed by `"\n"`, so the file gets one integer score per line.

# %% [markdown]
# ## Exercise 2: Load the File — `savegame.txt`
#
# Open `savegame.txt` for reading with a `with` block.
# Use `f.read()` to collect the raw text, then print it.
# Your notebook already created this file in Exercise 1.

# %% [markdown]
# ## Exercise 3: Load Scores into a List — `savegame.txt`
#
# Make an empty list named `loaded`.
# Open `savegame.txt`, then use `for line in f:` to loop over the file line-by-line.
# For each line, use `.strip()`, `int()`, and `.append()` to rebuild a list of integer scores.
# Remember: this loop walks through a file, not a list.

# %% [markdown]
# ## Exercise 4: Count the Saved Scores — `savegame.txt`
#
# Use `len()` on the integer list you loaded from `savegame.txt`.
# Print a friendly message that tells the player how many scores were saved.

# %% [markdown]
# ## Exercise 5: Save Settings — `settings.txt`
#
# Start with `settings = {"volume": 8, "difficulty": "easy"}`.
# Open `settings.txt` with a `with` block in `"w"` mode.
# Write `Ada`, `settings["volume"]`, and `settings["difficulty"]` as three text lines.
# Use `str()` for the volume and end every line with `"\n"`.

# %% [markdown]
# ## Exercise 6: Search the Settings — `settings.txt`
#
# Open `settings.txt` for reading and place all its text in a variable named `info`.
# Use the membership check `if "Ada" in info` to print a welcome-back message.
# Keep this file as text; do not turn its lines into integers.

# %% [markdown]
# ## Exercise 7: Save Then Load — `savegame.txt`
#
# Write one helper function that saves a list of integer scores to `savegame.txt` and another helper that loads the scores back into a list.
# Use `"w"` mode when saving.
# Call the helpers with a fixed list and print the loaded result to complete the round trip.

# %% [markdown]
# ## Exercise 8: Save My Score — `savegame.txt`
#
# **PROMPT:** In a game outside this notebook, you could ask the player for a score with `input("Your score? ")`.
# Do **not** call `input()` in the notebook code cell.
# Use the fixed placeholder `sample_score` below, convert it with `int()`, load the integer scores from `savegame.txt` (reuse your `load_scores` helper from Exercise 7), append the new integer score to the list, and re-save the whole list to `savegame.txt` in `"w"` mode.

# %%
sample_score = "1350"
# Write your save-point code here.

# %% [markdown]
# ## Exercise 9: Highest Saved Score — `savegame.txt`
#
# **Challenge:** Load all the integer scores from `savegame.txt` into a list.
# Use `max()` to find and print the highest saved score.

# %% [markdown]
# ## Exercise 10: Add a New High — `savegame.txt`
#
# **Challenge:** Load the integer score list from `savegame.txt`, use `.append()` to add a fixed new score, and re-save the whole list.
# Save with `"w"` mode, which REPLACES the file's old contents with your updated list (a fresh full save, not added onto the old file).
