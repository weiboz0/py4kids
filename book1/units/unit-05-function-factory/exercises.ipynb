# %% [markdown]
# # Function Factory Exercises
#
# Build, trace, repair, and design functions. Write and run notebook-safe Python in the blank cells, and write complete turtle programs in the `assets/` folder. In a blank code cell, write sentence answers inside a complete `print(...)` line so Python can read them.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Write a function named `cheer` with one parameter named `name`. Inside the function, build an f-string in a local variable named `message`, then return `message`. Call your function twice with two sample names. Store each returned value in a different variable outside the function and print both variables.
#
# Before you run it, predict the two output lines. Explain why the caller uses the returned values instead of trying to print the function's local `message` directly.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# This function call supplies a name, but the definition has no parameter to receive it. The broken code is shown as text. Repair it in the blank cell by adding the parameter, building the greeting in a local variable, and returning that local value. Store the returned value outside the function and print it, then explain what you changed.
#
# ```python
# def greeting_card():
#     print(f"Welcome, {name}!")
#
# greeting_card("Rin")
# ```

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Compare these two functions without running them.
#
# ```python
# def show_double(number):
#     print(number * 2)
#
# def get_double(number):
#     return number * 2
# ```
#
# Which function lets another calculation reuse the doubled number? Explain the difference between `print` and `return` in your own words. Then author your own `get_double(number)` function: store `number * 2` in a local variable named `doubled`, return it, and call it with `2.5`. Store the returned float value in `doubled_score`, compose it into the f-string `Doubling 2.5 gives 5.0.`, and print that message.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Write `area(w, h)`. Inside the function, store `w * h` in a local variable named `card_area`, then return it. Call the function with `w` equal to `8` and `h` equal to `2.5`. Store the returned value in a different variable outside the function, then use that outside variable in an f-string message.
#
# Predict whether the returned result will be a whole-number value or a float value before running the cell.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# Trace this code on paper.
#
# ```python
# team = "Comets"
#
# def player_label(name):
#     label = f"{team}: {name}"
#     print(label)
#
# player_label("Jo")
# print(team)
# ```
#
# Predict the exact two output lines. Which name is global? Which name is local? Explain why `print(label)` would cause a `NameError` if it were added after the function call.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# Open `assets/ex6_stamp_row.py`. Its tiny warm-up square is valid starter code, not the finished program. Replace the warm-up with a row of four square stamps. You must author all of these parts yourself in the asset:
#
# - an `import turtle` statement;
# - a color-setting line and a pen-down line;
# - an outer `for` loop for the four stamps;
# - `turtle.pensize(stamp_number + 1)` inside that outer loop, so the loop counter controls each stamp's pen width;
# - an inner `for` loop for the four sides of each stamp;
# - `forward` and `right` calls that close every square; and
# - pen-up movement between stamps so the connecting path is not drawn.
#
# Run the asset from the terminal. In the notebook cell below, write only a numeric proxy check: start `side_moves` at `0`, loop over the four `stamp_number` values, calculate `last_pen_size = stamp_number + 1`, add `4` to `side_moves` on each turn, and print the final pen size and side-move count. They should be `4` and `16`. Do not import or call turtle in the notebook.

# %%
# Numeric count check only; do not import turtle in this notebook.

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# Write `total_card_borders(number_of_cards)`. Inside the function, start a local variable named `total` at `0`. Loop over `range(number_of_cards)`. On each turn, calculate `side = 10 + card_number * 5`, calculate `border_length = side * 4`, then author the accumulator update `total = total + border_length`. Return the final `total`.
#
# Call the function for `4` cards, store the returned value outside the function, and print it. Predict the total before running your code, and explain why the return line belongs after the loop.

# %% [markdown]
# **More Practice**

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# This program raises a `NameError` because `card_label` is local to `make_label`, but the last line tries to use it outside the function. The broken program is text only; do not run it.
#
# ```python
# def make_label(name):
#     card_label = f"Made for {name}"
#
# make_label("Nia")
# print(card_label)
# ```
#
# Repair the program in the blank cell. Keep `card_label` local, return it from `make_label`, and have the caller store the returned value in a different variable before printing it. Then explain why the repaired final `print` can see the caller's variable.

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# Write `turn_angle(n)` so it returns `360 / n`. Then write `angle_message(angle)` so it returns an f-string that includes the angle. Compose the functions by feeding the returned float value from `turn_angle(7)` directly into a call to `angle_message`. Store the final returned message and print it. Predict why the message contains a decimal value.
#
# Both functions should return values rather than print inside their bodies. Name the local parameter in each function and explain how each returned value moves to the next part of the program.

# %% [markdown]
# ## Exercise 10

# %% [markdown]
# Open `assets/ex10_stamp_grid.py`. Replace its warm-up square with a grid containing `3` rows and `4` columns of square stamps. Choose a `size`, then define `stamp(size)` to draw one closed square. In the asset, author an `import turtle` statement, a color-setting line, a pen-down line, the outer row `for` line, and the inner column `for` line. Call `stamp(size)` inside the inner loop. Use only `forward`, `backward`, `left` (`left` turns the other way), and `right` for movement and turns. Use pen-up movement between stamps and rows.
#
# Also start `stamps_drawn` at `0`, author `stamps_drawn = stamps_drawn + 1` inside the inner loop, and print the final count. Run the asset from the terminal. In the notebook cell below, write only a non-turtle numeric proxy check: use the same nested loops and accumulator update, then print the final count. It should be `12`.

# %%
# Numeric count check only; do not import turtle in this notebook.

# %% [markdown]
# ## Exercise 11

# %% [markdown]
# Open `assets/ex11_stamp_bands.py`. Replace its warm-up square with `2` bands of `5` square stamps. Define or reuse `stamp(size)` from Exercise 10. In the asset, author an `import turtle` statement, a color-setting line, a pen-down line, an outer `for` line for the bands, and an inner `for` line for the stamps. Use the outer counter in `size = 15 + band_number * 5` to change the stamp size. Use only `forward`, `backward`, `left` (`left` turns the other way), and `right` for movement and turns, with pen-up movement between stamps.
#
# Start `stamps_drawn` at `0`, author `stamps_drawn = stamps_drawn + 1` inside the inner loop, and print the final count. Run the asset from the terminal. In the notebook cell below, write only a non-turtle numeric proxy check: use the same nested loops, size formula, and accumulator update, then print the final size and count. They should be `20` and `10`.

# %%
# Numeric count check only; do not import turtle in this notebook.

# %% [markdown]
# ## Challenge

# %% [markdown]
# Try these after the eleven core exercises.

# %% [markdown]
# ### Challenge 1
#
# Build a name-badge factory. Define `name_badge(name, club)` with two parameters. It should print a pen-stroke-style border made from text symbols and an f-string containing both values. Call it twice with sample values and predict the output first.

# %% [markdown]
# ### Challenge 2
#
# Plan a flower stamp without recursion: `flower` must call `petal` inside a loop, and neither function may call itself. Complete the written plan and predict how many petals one call draws. Keep it in this markdown fence; do not run turtle here.
#
# ```python
# def petal(size):
#     ____
#
# def flower(size, petal_count):
#     for petal_number in range(petal_count):
#         ____
#         turtle.right(360 / petal_count)
# ```
