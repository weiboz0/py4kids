# %% [markdown]
# # Function Factory Exercises
#
# Build, trace, repair, and design functions. Keep turtle work as a written plan here; run complete drawing scripts from the `assets/` folder. In a blank code cell, write sentence answers inside a complete `print(...)` line so Python can read them.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Write a function named `cheer` with one parameter named `name`. It should print an f-string that includes the name and an encouraging message. Call your function twice with two sample names.
#
# Before you run it, predict the two output lines.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# This function call supplies a name, but the definition has no parameter to receive it. The broken code is shown as text. Repair it in the blank cell, then explain what you changed.
#
# ```python
# def greeting_card():
#     print(f"Welcome, {name}!")
#
# greeting_card("Rin")
# ```

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Compare these two functions without running them.
#
# ```python
# def show_double(number):
#     print(number * 2)
#
# def get_double(number):
#     return number * 2
# ```
#
# Which function lets another calculation reuse the doubled number? Explain the difference between `print` and `return` in your own words. Then write one call whose returned value is stored in `doubled_score`. (For example, double the number 7.)

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Write `area(w, h)` so it returns `w * h`. Call it with `w` equal to `8` and `h` equal to `2.5`. Store the result, then use that result in an f-string message.
#
# Predict whether the returned result will be a whole-number value or a float value before running the cell.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# Trace this code on paper.
#
# ```python
# team = "Comets"
#
# def player_label(name):
#     label = f"{team}: {name}"
#     print(label)
#
# player_label("Jo")
# print(team)
# ```
#
# Predict the exact two output lines. Which name is global? Which name is local? Explain why `print(label)` would cause a `NameError` if it were added after the function call.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# Design a closed turtle stamp without running turtle in this notebook. The incomplete plan is shown as text. Replace each blank on paper. Make the outer counter change both the stamp size and the distance moved before the stamp.
#
# ```python
# def stamp(size):
#     for edge in range(4):
#         turtle.forward(size)
#         turtle.right(____)
#
# stamp_count = 4
# for stamp_number in range(stamp_count):
#     size = 20 + stamp_number * ____
#     distance = stamp_number * ____
#     turtle.penup()
#     turtle.forward(distance)
#     turtle.pendown()
#     stamp(size)
# ```
#
# Record the four counter values and calculate the size and distance for each one. Explain how a function prevents four copies of the stamp commands.

# %% [markdown]
# ## Challenge

# %% [markdown]
# Try these after the six core exercises.

# %% [markdown]
# ### Challenge 1
#
# Build a name-badge factory. Define `name_badge(name, club)` with two parameters. It should print a pen-stroke-style border made from text symbols and an f-string containing both values. Call it twice with sample values and predict the output first.

# %% [markdown]
# ### Challenge 2
#
# Plan a flower stamp without recursion: `flower` must call `petal` inside a loop, and neither function may call itself. Complete the written plan and predict how many petals one call draws. Keep it in this markdown fence; do not run turtle here.
#
# ```python
# def petal(size):
#     ____
#
# def flower(size, petal_count):
#     for petal_number in range(petal_count):
#         ____
#         turtle.right(360 / petal_count)
# ```
