# %% [markdown]
# # Output & Variables Practice
#
# **Core: Exercises 1–7 and 12–14** are the in-class path. **Extra practice: Exercises 8–11** and **More Practice: Exercises 15–18** add variety. **Challenges: Exercises 19–20** are optional stretch work; no core exercise depends on them.

# %% [markdown]
# For every exercise, follow the specification and produce the exact output shown. Run your cell and compare every capital letter, space, and punctuation mark with the worked sample. Write the lines directly.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Welcome Sign
#
# A classroom club wants one clear line at the top of its sign so visitors know they are in the right place.
#
# **Specification:** Given the string variable `club_name`, print exactly `Welcome to <club_name>!` on one line.
#
# **Worked sample — given values:**
#
# ```python
# club_name = "Code Crew"
# ```
#
# **Expected output:**
#
# ```text
# Welcome to Code Crew!
# ```
#
# **Real version:** the real program reads a club name with input() — see the solution.

# %%
club_name = "Code Crew"

# Print the exact welcome sign.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Supply Label
#
# A shared shelf needs a tidy label that says what an item is and where it belongs. A short comment will help the next programmer understand the two output lines.
#
# **Specification:** Given `item` and `location`, add a comment that describes the program, then print exactly two lines: `Item: <item>` and `Location: <location>`.
#
# **Worked sample — given values:**
#
# ```python
# item = "markers"
# location = "blue bin"
# ```
#
# **Expected output:**
#
# ```text
# Item: markers
# Location: blue bin
# ```
#
# **Real version:** the real program reads an item and a location with input() — see the solution.

# %%
item = "markers"
location = "blue bin"

# Add your comment and exact output.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Repeat the Motto
#
# A practice group says the same short motto three times before it begins. Reusing one variable keeps all three lines consistent.
#
# **Specification:** Given `motto`, print its value on three separate lines. Write three `print()` instructions directly.
#
# **Worked sample — given values:**
#
# ```python
# motto = "Keep trying"
# ```
#
# **Expected output:**
#
# ```text
# Keep trying
# Keep trying
# Keep trying
# ```
#
# **Real version:** the real program reads a motto with input() — see the solution.

# %%
motto = "Keep trying"

# Print the motto three times.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Full-Name Label
#
# A name tag stores the first and last names separately but must display them together with exactly one space.
#
# **Specification:** Given `first_name` and `last_name`, use string concatenation with `+` to print exactly `Name: <first_name> <last_name>`. Do not use an f-string.
#
# **Worked sample — given values:**
#
# ```python
# first_name = "Ari"
# last_name = "Lopez"
# ```
#
# **Expected output:**
#
# ```text
# Name: Ari Lopez
# ```
#
# **Real version:** the real program reads a first name and a last name with input() — see the solution.

# %%
first_name = "Ari"
last_name = "Lopez"

# Join the label, names, and needed space with +.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Team Greeting
#
# A team dashboard greets one member and reminds them which team they joined. The names change, but the sentence format stays fixed.
#
# **Specification:** Given `member_name` and `team_name`, use one f-string to print exactly `Hello, <member_name>! Welcome to <team_name>.`
#
# **Worked sample — given values:**
#
# ```python
# member_name = "Nia"
# team_name = "Blue Rockets"
# ```
#
# **Expected output:**
#
# ```text
# Hello, Nia! Welcome to Blue Rockets.
# ```
#
# **Real version:** the real program reads a member name and a team name with input() — see the solution.

# %%
member_name = "Nia"
team_name = "Blue Rockets"

# Print the exact greeting with one f-string.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ### Repair the Badge
#
# A badge printer stops before showing its label because one string literal never closes. Read the final traceback line, then repair the punctuation.
#
# **Specification:** Fix the broken instruction without changing its words so it prints exactly `Visitor badge ready!`. Put the repaired instruction in the empty cell.
#
# **Worked sample — broken instruction:**
#
# ```python
# print("Visitor badge ready!)
# ```
#
# **Expected output after the repair:**
#
# ```text
# Visitor badge ready!
# ```
#
# **No real version:** this exercise fixes (or traces) code rather than reading input.

# %%
print("Visitor badge ready!)

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# ### Club Meeting Reminder
#
# A club reminder needs to save both the club's name and its meeting day before it can print a complete sentence.
#
# **Specification:** Choose two clear variable names. Write assignments that store a club name and a meeting day, then use both variables to print exactly `<club> meets on <day>.`
#
# **Worked sample:**
#
# ```python
# club_name = "Robotics Club"
# meeting_day = "Tuesday"
# ```
#
# **Expected output:**
#
# ```text
# Robotics Club meets on Tuesday.
# ```
#
# **Real version:** the real program reads a club name and a meeting day with input() — see the solution.

# %%
# Create two clearly named variables, then print the exact reminder.

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# ### Fixed-Value Greeting
#
# An interactive greeter would usually collect a name from a person. For repeatable notebook practice, the reply is already stored as a fixed string.
#
# The lesson has a runnable-at-home `input()` cell. For this exercise, keep the provided assignment.
#
# **Specification:** Given `name`, print exactly `Nice to meet you, <name>!` using an f-string.
#
# **Worked sample — given values:**
#
# ```python
# name = "Sam"
# ```
#
# **Expected output:**
#
# ```text
# Nice to meet you, Sam!
# ```
#
# **Real version:** the real program reads a name with input() — see the solution.

# %%
name = "Sam"

# Print the exact greeting.

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# ### Tidy Fact Card
#
# A club welcome board needs the same four-line layout for every member, with only the three facts changing.
#
# **Specification:** Given `member_name`, `favorite_color`, and `home_city`, print the title `CLUB FACT CARD`, then print `Name: <member_name>`, `Favorite color: <favorite_color>`, and `Hometown: <home_city>` on the next three lines.
#
# **Worked sample — given values:**
#
# ```python
# member_name = "Jordan"
# favorite_color = "orange"
# home_city = "Fresno"
# ```
#
# **Expected output:**
#
# ```text
# CLUB FACT CARD
# Name: Jordan
# Favorite color: orange
# Hometown: Fresno
# ```
#
# **Real version:** the real program reads a member name, a favorite color, and a home city with input() — see the solution.

# %%
member_name = "Jordan"
favorite_color = "orange"
home_city = "Fresno"

# Print the exact four-line card.

# %% [markdown]
# ## Exercise 10

# %% [markdown]
# ### Apostrophe Notice
#
# A pickup desk needs a natural-sounding sentence with an apostrophe in the owner's name phrase. Choosing matching quotes keeps the punctuation readable.
#
# **Specification:** Given `owner` and `item`, print exactly `<owner>'s <item> is ready.` Use the variables in the output and preserve the apostrophe and period.
#
# **Worked sample — given values:**
#
# ```python
# owner = "Maya"
# item = "notebook"
# ```
#
# **Expected output:**
#
# ```text
# Maya's notebook is ready.
# ```
#
# **Real version:** the real program reads an owner and an item with input() — see the solution.

# %%
owner = "Maya"
item = "notebook"

# Print the exact pickup notice.

# %% [markdown]
# ## Exercise 11

# %% [markdown]
# ### Event Ticket
#
# A small event ticket uses a title, a blank line, and two labeled facts so the important details are easy to scan.
#
# **Specification:** Given `event_name` and `event_day`, print `EVENT TICKET`, then a blank line, then `Event: <event_name>` and `Day: <event_day>`.
#
# **Worked sample — given values:**
#
# ```python
# event_name = "Game Night"
# event_day = "Friday"
# ```
#
# **Expected output:**
#
# ```text
# EVENT TICKET
#
# Event: Game Night
# Day: Friday
# ```
#
# **Real version:** the real program reads an event name and an event day with input() — see the solution.

# %%
event_name = "Game Night"
event_day = "Friday"

# Print the ticket with the exact blank line.

# %% [markdown]
# ## Exercise 12

# %% [markdown]
# ### Comma Print
#
# The club board needs two short labels that students can read at a glance.
#
# **Specification:** Given `club` and `room`, write a purpose comment, then use a comma in each `print()` call to show the two labels with one space after each colon.
#
# **Worked sample — given values:**
#
# ```python
# club = "Origami"
# room = "B12"
# ```
#
# **Expected output:**
#
# ```text
# Club: Origami
# Room: B12
# ```
#
# **Real version:** the real program reads a club and a room with input() — see the solution.

# %%
club = "Origami"
room = "B12"
# Use the given club and room; add a purpose comment and print both labels.

# %% [markdown]
# ## Exercise 13

# %% [markdown]
# ### Room Sign
#
# A hallway sign combines a building name and room number into one clear direction.
#
# **Specification:** Given `building` and `room_number`, write a purpose comment, then use string `+` to print exactly the sign shown.
#
# **Worked sample — given values:**
#
# ```python
# building = "West"
# room_number = "204"
# ```
#
# **Expected output:**
#
# ```text
# West Wing, Room 204
# ```
#
# **Real version:** the real program reads a building and a room number with input() — see the solution.

# %%
building = "West"
room_number = "204"
# Use the given building and room number; add a purpose comment and build the sign with +.

# %% [markdown]
# ## Exercise 14

# %% [markdown]
# ### Escape Poem
#
# A tiny poem needs three lines, with the last line indented like a closing note.
#
# **Specification:** Write a purpose comment. Save the exact poem as one string using `\n` and `\t`, then print that string once.
#
# **Worked sample — given values:**
#
# ```python
# poem = "Sun comes up\nBirds sing\n\tThe end"
# ```
#
# **Expected output:**
#
# ```text
# Sun comes up
# Birds sing
# 	The end
# ```
#
# **No real version:** this exercise prints fixed art.

# %%
# Add a purpose comment, save one escaped string, and print it once.

# %% [markdown]
# ## Exercise 15

# %% [markdown]
# ### More Practice: Predict the Output
#
# A printer has three settings to trace. Work out the visible lines without changing the code.
#
# **Specification:** Predict the output of each snippet in order. The third snippet has two `print()` calls but makes one output line.
#
# **Worked sample — given values:**
#
# ```python
# print("A", "B")
# print("x", "y", "z", sep="-")
# print("Go", end="!")
# print("Now")
# ```
#
# **Expected output:**
#
# ```text
# A B
# x-y-z
# Go!Now
# ```
#
# **No real version:** this exercise fixes (or traces) code rather than reading input.

# %%
# Write your three predictions as comments; do not run new output code.

# %% [markdown]
# ## Exercise 16

# %% [markdown]
# ### More Practice: Swap Two Values
#
# Two labels have the wrong saved fruit. A temporary variable can keep one value safe while the other changes.
#
# **Specification:** Given `left` and `right`, swap their saved values using a third variable. Print `left: <left>` and `right: <right>` after the swap.
#
# **Worked sample — given values:**
#
# ```python
# left = "pear"
# right = "plum"
# ```
#
# **Expected output:**
#
# ```text
# left: plum
# right: pear
# ```
#
# **Real version:** the real program reads a left value and a right value with input() — see the solution.

# %%
left = "pear"
right = "plum"
# Use the given left and right values; swap them with a temporary variable and print both labels.

# %% [markdown]
# ## Exercise 17

# %% [markdown]
# ### More Practice: Fix the NameError
#
# A fruit label crashes because the printed name uses different capitalization from the assignment.
#
# **Specification:** Read the broken instruction, then repair only the variable name so the program prints the saved fruit.
#
# **Worked sample — given values:**
#
# ```python
# favorite = "mango"
# print(Favorite)
# ```
#
# **Expected output:**
#
# ```text
# mango
# ```
#
# **No real version:** this exercise fixes (or traces) code rather than reading input.

# %%
# Copy the broken program here and fix its variable name.

# %% [markdown]
# ## Exercise 18

# %% [markdown]
# ### More Practice: Triple-Quote Cat
#
# A fixed cat drawing fits in one triple-quoted string.
#
# **Specification:** Save the three rows below as one triple-quoted string, with no leading or trailing newline. Print the string once.
#
# **Worked sample — given values:**
#
# ```python
# cat = """=^.^=
# (   )
#  | |"""
# ```
#
# **Expected output:**
#
# ```text
# =^.^=
# (   )
#  | |
# ```
#
# **No real version:** this exercise prints fixed art.

# %%
# Save the exact cat in one triple-quoted string, then print it once.

# %% [markdown]
# ## Exercise 19

# %% [markdown]
# ### Challenge 1: Two Member Badges
#
# A welcome table must print two badges with the same format. One pair of variables can hold the first member's facts and then be reassigned for the second member.
#
# **Specification:** Set `member_name` and `member_color` to the first pair of values and print the first two-line badge. Print one blank line, reassign the same two variables to the second pair of values, and print the second badge. Each badge uses `Member: <name>` followed by `Color: <color>`. Write the lines directly.
#
# **Worked sample — given values:**
#
# ```python
# member_name = "Inez"
# member_color = "gold"
# # After printing the first badge:
# member_name = "Omar"
# member_color = "green"
# ```
#
# **Expected output:**
#
# ```text
# Member: Inez
# Color: gold
#
# Member: Omar
# Color: green
# ```
#
# **Real version:** the real program reads two member names and their colors with input() — see the solution.

# %%
member_name = "Inez"
member_color = "gold"

# Print the first badge, reassign the same variables, and print the second badge.

# %% [markdown]
# ## Exercise 20

# %% [markdown]
# ### Challenge 2: Error Detective Card
#
# A three-line activity card has two independent mistakes: one variable name changes spelling, and the final string is missing a closing quote. Run the program and read the error that the traceback shows first: a `SyntaxError` from the unclosed quote. Fix that quote and run the program again. Then fix the `NameError` that the next run reveals.
#
# **Specification:** Repair only the mistakes in the broken program so it prints the exact three-line card shown below. Keep the given values and labels unchanged. Put the repaired program in the empty cell.
#
# **Worked sample — given values:**
#
# ```python
# activity_name = "Puzzle Lab"
# room_name = "Room B"
# ```
#
# **Expected output after both repairs:**
#
# ```text
# ACTIVITY CARD
# Activity: Puzzle Lab
# Room: Room B
# ```
#
# **No real version:** this exercise fixes (or traces) code rather than reading input.

# %%
activity_name = "Puzzle Lab"
room_name = "Room B"
print("ACTIVITY CARD")
print(f"Activity: {activity}")
print("Room: + room_name)
