# %% [markdown]
# # Output & Variables Solutions
#
# These sample answers use the exercises' fixed values so the notebook runs without stopping for keyboard input.

# %% [markdown]
# > **Note for teachers:** the `assert` lines are automatic self-checks for CI and for you — students don't need to read or understand them.

# %% [markdown]
# ## Exercise 1
#
# ### Welcome Sign

# %%
club_name = "Code Crew"
line_1 = f"Welcome to {club_name}!"
print(line_1)
assert line_1 == "Welcome to Code Crew!"

# %% [markdown]
# **The real program** (reads a club name):
#
# ```python
# club_name = input()
# line_1 = f"Welcome to {club_name}!"
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# Code Crew
# ```
#
# Expected output:
#
# ```text
# Welcome to Code Crew!
# ```

# %% [markdown]
# ## Exercise 2
#
# ### Supply Label

# %%
# Build a two-line label for the shared supply shelf.
item = "markers"
location = "blue bin"
line_1 = f"Item: {item}"
print(line_1)
assert line_1 == "Item: markers"
line_2 = f"Location: {location}"
print(line_2)
assert line_2 == "Location: blue bin"

# %% [markdown]
# **The real program** (reads an item and a location):
#
# ```python
# item = input()
# location = input()
# line_1 = f"Item: {item}"
# print(line_1)
# line_2 = f"Location: {location}"
# print(line_2)
# ```
#
# Sample input:
#
# ```text
# markers
# blue bin
# ```
#
# Expected output:
#
# ```text
# Item: markers
# Location: blue bin
# ```

# %% [markdown]
# ## Exercise 3
#
# ### Repeat the Motto

# %%
motto = "Keep trying"
line_1 = motto
print(line_1)
assert line_1 == "Keep trying"
line_2 = motto
print(line_2)
assert line_2 == "Keep trying"
line_3 = motto
print(line_3)
assert line_3 == "Keep trying"

# %% [markdown]
# **The real program** (reads a motto):
#
# ```python
# motto = input()
# line_1 = motto
# print(line_1)
# line_2 = motto
# print(line_2)
# line_3 = motto
# print(line_3)
# ```
#
# Sample input:
#
# ```text
# Keep trying
# ```
#
# Expected output:
#
# ```text
# Keep trying
# Keep trying
# Keep trying
# ```

# %% [markdown]
# ## Exercise 4
#
# ### Full-Name Label

# %%
first_name = "Ari"
last_name = "Lopez"
line_1 = "Name: " + first_name + " " + last_name
print(line_1)
assert line_1 == "Name: Ari Lopez"

# %% [markdown]
# **The real program** (reads a first name and a last name):
#
# ```python
# first_name = input()
# last_name = input()
# line_1 = "Name: " + first_name + " " + last_name
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# Ari
# Lopez
# ```
#
# Expected output:
#
# ```text
# Name: Ari Lopez
# ```

# %% [markdown]
# ## Exercise 5
#
# ### Team Greeting

# %%
member_name = "Nia"
team_name = "Blue Rockets"
line_1 = f"Hello, {member_name}! Welcome to {team_name}."
print(line_1)
assert line_1 == "Hello, Nia! Welcome to Blue Rockets."

# %% [markdown]
# **The real program** (reads a member name and a team name):
#
# ```python
# member_name = input()
# team_name = input()
# line_1 = f"Hello, {member_name}! Welcome to {team_name}."
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# Nia
# Blue Rockets
# ```
#
# Expected output:
#
# ```text
# Hello, Nia! Welcome to Blue Rockets.
# ```

# %% [markdown]
# ## Exercise 6
#
# ### Repair the Badge

# %%
line_1 = "Visitor badge ready!"
print(line_1)
assert line_1 == "Visitor badge ready!"

# %% [markdown]
# ## Exercise 7
#
# ### Club Meeting Reminder

# %%
club_name = "Robotics Club"
meeting_day = "Tuesday"
line_1 = f"{club_name} meets on {meeting_day}."
print(line_1)
assert line_1 == "Robotics Club meets on Tuesday."

# %% [markdown]
# **The real program** (reads a club name and a meeting day):
#
# ```python
# club_name = input()
# meeting_day = input()
# line_1 = f"{club_name} meets on {meeting_day}."
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# Robotics Club
# Tuesday
# ```
#
# Expected output:
#
# ```text
# Robotics Club meets on Tuesday.
# ```

# %% [markdown]
# ## Exercise 8
#
# ### Fixed-Value Greeting

# %%
name = "Sam"
line_1 = f"Nice to meet you, {name}!"
print(line_1)
assert line_1 == "Nice to meet you, Sam!"

# %% [markdown]
# **The real program** (reads a name):
#
# ```python
# name = input()
# line_1 = f"Nice to meet you, {name}!"
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# Sam
# ```
#
# Expected output:
#
# ```text
# Nice to meet you, Sam!
# ```

# %% [markdown]
# ## Exercise 9
#
# ### Tidy Fact Card

# %%
member_name = "Jordan"
favorite_color = "orange"
home_city = "Fresno"
line_1 = "CLUB FACT CARD"
print(line_1)
assert line_1 == "CLUB FACT CARD"
line_2 = f"Name: {member_name}"
print(line_2)
assert line_2 == "Name: Jordan"
line_3 = f"Favorite color: {favorite_color}"
print(line_3)
assert line_3 == "Favorite color: orange"
line_4 = f"Hometown: {home_city}"
print(line_4)
assert line_4 == "Hometown: Fresno"

# %% [markdown]
# **The real program** (reads a member name, a favorite color, and a home city):
#
# ```python
# member_name = input()
# favorite_color = input()
# home_city = input()
# line_1 = "CLUB FACT CARD"
# print(line_1)
# line_2 = f"Name: {member_name}"
# print(line_2)
# line_3 = f"Favorite color: {favorite_color}"
# print(line_3)
# line_4 = f"Hometown: {home_city}"
# print(line_4)
# ```
#
# Sample input:
#
# ```text
# Jordan
# orange
# Fresno
# ```
#
# Expected output:
#
# ```text
# CLUB FACT CARD
# Name: Jordan
# Favorite color: orange
# Hometown: Fresno
# ```

# %% [markdown]
# ## Exercise 10
#
# ### Apostrophe Notice

# %%
owner = "Maya"
item = "notebook"
line_1 = f"{owner}'s {item} is ready."
print(line_1)
assert line_1 == "Maya's notebook is ready."

# %% [markdown]
# **The real program** (reads an owner and an item):
#
# ```python
# owner = input()
# item = input()
# line_1 = f"{owner}'s {item} is ready."
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# Maya
# notebook
# ```
#
# Expected output:
#
# ```text
# Maya's notebook is ready.
# ```

# %% [markdown]
# ## Exercise 11
#
# ### Event Ticket

# %%
event_name = "Game Night"
event_day = "Friday"
line_1 = "EVENT TICKET"
print(line_1)
assert line_1 == "EVENT TICKET"
line_2 = ""
print(line_2)
assert line_2 == ""
line_3 = f"Event: {event_name}"
print(line_3)
assert line_3 == "Event: Game Night"
line_4 = f"Day: {event_day}"
print(line_4)
assert line_4 == "Day: Friday"

# %% [markdown]
# **The real program** (reads an event name and an event day):
#
# ```python
# event_name = input()
# event_day = input()
# line_1 = "EVENT TICKET"
# print(line_1)
# line_2 = ""
# print(line_2)
# line_3 = f"Event: {event_name}"
# print(line_3)
# line_4 = f"Day: {event_day}"
# print(line_4)
# ```
#
# Sample input:
#
# ```text
# Game Night
# Friday
# ```
#
# Expected output:
#
# ```text
# EVENT TICKET
#
# Event: Game Night
# Day: Friday
# ```

# %% [markdown]
# ## Exercise 12
#
# ### Comma Print

# %%
# Show the club and room on the club board.
club = "Origami"
room = "B12"
line_1 = "Club: " + club
print("Club:", club)
assert line_1 == "Club: Origami"
line_2 = "Room: " + room
print("Room:", room)
assert line_2 == "Room: B12"

# %% [markdown]
# **The real program** (reads a club and a room):
#
# ```python
# club = input()
# room = input()
# line_1 = "Club: " + club
# print("Club:", club)
# line_2 = "Room: " + room
# print("Room:", room)
# ```
#
# Sample input:
#
# ```text
# Origami
# B12
# ```
#
# Expected output:
#
# ```text
# Club: Origami
# Room: B12
# ```

# %% [markdown]
# ## Exercise 13
#
# ### Room Sign

# %%
# Point visitors toward the right room.
building = "West"
room_number = "204"
line_1 = building + " Wing, Room " + room_number
print(line_1)
assert line_1 == "West Wing, Room 204"

# %% [markdown]
# **The real program** (reads a building and a room number):
#
# ```python
# building = input()
# room_number = input()
# line_1 = building + " Wing, Room " + room_number
# print(line_1)
# ```
#
# Sample input:
#
# ```text
# West
# 204
# ```
#
# Expected output:
#
# ```text
# West Wing, Room 204
# ```

# %% [markdown]
# ## Exercise 14
#
# ### Escape Poem

# %%
# Print the three-line poem with an indented ending.
poem = "Sun comes up\nBirds sing\n\tThe end"
line_1 = poem
print(line_1)
assert line_1 == "Sun comes up\nBirds sing\n\tThe end"

# %% [markdown]
# ## Exercise 15
#
# ### More Practice: Predict the Output

# %%
line_1 = "A B"
print("A", "B")
assert line_1 == "A B"
line_2 = "x-y-z"
print("x", "y", "z", sep="-")
assert line_2 == "x-y-z"
line_3 = "Go!Now"
print("Go", end="!")
print("Now")
assert line_3 == "Go!Now"

# %% [markdown]
# ## Exercise 16
#
# ### More Practice: Swap Two Values

# %%
left = "pear"
right = "plum"
temporary = left
left = right
right = temporary
line_1 = f"left: {left}"
print(line_1)
assert line_1 == "left: plum"
line_2 = f"right: {right}"
print(line_2)
assert line_2 == "right: pear"

# %% [markdown]
# **The real program** (reads a left value and a right value):
#
# ```python
# left = input()
# right = input()
# temporary = left
# left = right
# right = temporary
# line_1 = f"left: {left}"
# print(line_1)
# line_2 = f"right: {right}"
# print(line_2)
# ```
#
# Sample input:
#
# ```text
# pear
# plum
# ```
#
# Expected output:
#
# ```text
# left: plum
# right: pear
# ```

# %% [markdown]
# ## Exercise 17
#
# ### More Practice: Fix the NameError

# %%
favorite = "mango"
line_1 = favorite
print(line_1)
assert line_1 == "mango"

# %% [markdown]
# ## Exercise 18
#
# ### More Practice: Triple-Quote Cat

# %%
cat = """=^.^=
(   )
 | |"""
line_1 = cat
print(line_1)
assert line_1 == "=^.^=\n(   )\n | |"

# %% [markdown]
# ## Exercise 19
#
# ### Challenge 1: Two Member Badges

# %%
member_name = "Inez"
member_color = "gold"
line_1 = f"Member: {member_name}"
print(line_1)
assert line_1 == "Member: Inez"
line_2 = f"Color: {member_color}"
print(line_2)
assert line_2 == "Color: gold"
line_3 = ""
print(line_3)
assert line_3 == ""
member_name = "Omar"
member_color = "green"
line_4 = f"Member: {member_name}"
print(line_4)
assert line_4 == "Member: Omar"
line_5 = f"Color: {member_color}"
print(line_5)
assert line_5 == "Color: green"

# %% [markdown]
# **The real program** (reads two member names and their colors):
#
# ```python
# member_name = input()
# member_color = input()
# line_1 = f"Member: {member_name}"
# print(line_1)
# line_2 = f"Color: {member_color}"
# print(line_2)
# line_3 = ""
# print(line_3)
# member_name = input()
# member_color = input()
# line_4 = f"Member: {member_name}"
# print(line_4)
# line_5 = f"Color: {member_color}"
# print(line_5)
# ```
#
# Sample input:
#
# ```text
# Inez
# gold
# Omar
# green
# ```
#
# Expected output:
#
# ```text
# Member: Inez
# Color: gold
#
# Member: Omar
# Color: green
# ```

# %% [markdown]
# ## Exercise 20
#
# ### Challenge 2: Error Detective Card

# %%
activity_name = "Puzzle Lab"
room_name = "Room B"
line_1 = "ACTIVITY CARD"
line_2 = f"Activity: {activity_name}"
line_3 = "Room: " + room_name
print(line_1)
print(line_2)
print(line_3)
assert line_1 == "ACTIVITY CARD"
assert line_2 == "Activity: Puzzle Lab"
assert line_3 == "Room: Room B"
