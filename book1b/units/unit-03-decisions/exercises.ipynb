# %% [markdown]
# # Decisions Practice
#
# **Core: Exercises 1–10** are the in-class path. **More Practice: Exercises 11–16** add variety. **Challenges: Exercises 17–21** are optional stretch work; no core exercise depends on them.

# %% [markdown]
# For every exercise, follow the specification and produce the exact output shown. Run your cell and compare every capital letter, space, and punctuation mark with the worked sample. Write the lines directly.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Target Message
#
# A practice board congratulates a player only when the given score reaches the target.
#
# **Specification:** Given `score`, use an `if` statement to print `Target reached!` only when the score is at least 10.
#
# **Worked sample — given values:**
#
# ```python
# score = 12
# ```
#
# **Expected output:**
#
# ```text
# Target reached!
# ```
#
# **Real version:** the real program reads a score with input() — see the solution.

# %%
score = 12

# Print the message only when the target is reached.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Even or Odd
#
# A label needs one of two messages based on the remainder after division by 2.
#
# **Specification:** Given the non-negative integer `number`, use `if` and `else` to print `Even` when its remainder after division by 2 is 0. Otherwise print `Odd`.
#
# **Worked sample — given values:**
#
# ```python
# number = 17
# ```
#
# **Expected output:**
#
# ```text
# Odd
# ```
#
# **Real version:** the real program reads a number with input() — see the solution.

# %%
number = 17

# Choose and print the exact label.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Inclusive Range
#
# A number checker accepts values from 0 through 10, including both endpoints.
#
# **Specification:** Given `x`, use either `x >= 0 and x <= 10` or `0 <= x <= 10`. Print `<x> is in range.` when it is true; otherwise print `<x> is out of range.`
#
# **Worked sample — given values:**
#
# ```python
# x = 10
# ```
#
# **Expected output:**
#
# ```text
# 10 is in range.
# ```
#
# **Real version:** the real program reads a number to check with input() — see the solution.

# %%
x = 10

# Check the inclusive range and print one exact message.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Weekend Label
#
# A schedule labels Saturday and Sunday as weekend days.
#
# **Specification:** Given `day`, use `or` to print `Weekend` when the value is `"Saturday"` or `"Sunday"`. Otherwise print `Weekday`.
#
# **Worked sample — given values:**
#
# ```python
# day = "Sunday"
# ```
#
# **Expected output:**
#
# ```text
# Weekend
# ```
#
# **Real version:** the real program reads a day name with input() — see the solution.

# %%
day = "Sunday"

# Join the two equality tests with or and print the label.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Medal Ladder
#
# A score receives the first medal threshold it reaches. Several thresholds can be true at once, so their order controls the answer.
#
# **Specification:** Given `score`, use one top-down `if`/`elif`/`elif`/`else` ladder. Check `score >= 90` for `Gold` first, then `score >= 80` for `Silver`, then `score >= 70` for `Bronze`; otherwise print `Practice round`.
#
# **Worked sample — given values:**
#
# ```python
# score = 95
# ```
#
# **Expected output:**
#
# ```text
# Gold
# ```
#
# **Notice:** 95 also passes the Silver and Bronze thresholds. The expected output is correct only when the highest threshold is checked first, because the first matching branch wins.
#
# **Real version:** the real program reads a score with input() — see the solution.

# %%
score = 95

# Check thresholds from highest to lowest and print one label.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ### Repair the Exact-Score Check
#
# An exact-score program stops with a `SyntaxError` because the condition uses assignment instead of an equality comparison.
#
# **Specification:** Repair only the condition so the program prints exactly `Exact score!`. Put the repaired program in the empty cell.
#
# **Worked sample — broken program:**
#
# ```python
# score = 90
# if score = 90:
#     print("Exact score!")
# ```
#
# **Expected output after the repair:**
#
# ```text
# Exact score!
# ```
#
# **No real version:** this exercise fixes code rather than reading input.

# %%
score = 90
if score = 90:
    print("Exact score!")

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# ### Permission and Score
#
# An activity requires permission first. A score requirement matters only after permission is present.
#
# **Specification:** Given `has_permission` and `score`, use a nested decision. Without permission, print `Permission needed`. With permission and a score of at least 7, print `Activity unlocked`; with permission and a lower score, print `Raise the score`.
#
# **Worked sample — given values:**
#
# ```python
# has_permission = True
# score = 5
# ```
#
# **Expected output:**
#
# ```text
# Raise the score
# ```
#
# **Real version:** the real program reads whether permission is present and a score with input() — see the solution.

# %%
has_permission = True
score = 5

# Use a nested decision and print one exact message.

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# ### Temperature Check
#
# A temperature checker chooses one of two labels from a reading supplied as text.
#
# **Specification:** Given `temperature_text`, convert it with `int()`. Print `Freezing` when the number is at most 32; otherwise print `Above freezing`.
#
# **Worked sample — given values:**
#
# ```python
# temperature_text = "30"
# ```
#
# **Expected output:**
#
# ```text
# Freezing
# ```
#
# **Real version:** the real program reads a temperature as text with input() — see the solution.

# %%
temperature_text = "30"

# Convert the fixed value, choose, and print.

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# ### FizzBuzz for One Number
#
# A single number needs its FizzBuzz label.
#
# **Specification:** Given `n`, check divisibility by 15 first, then 3, then 5. Print `FizzBuzz`, `Fizz`, or `Buzz` for those cases; otherwise print the number itself (for example, 7 prints `7`). Use an `if`/`elif`/`else` ladder.
#
# **Worked sample — given values:**
#
# ```python
# n = 75
# ```
#
# **Expected output:**
#
# ```text
# FizzBuzz
# ```
#
# **Real version:** the real program reads one number with input() — see the solution.

# %%
# Check 15 first, then 3, then 5, and print one label.

# %% [markdown]
# ## Exercise 10

# %% [markdown]
# ### Largest of Three
#
# Three scores need one winning value.
#
# **Specification:** Given `a`, `b`, and `c`, compare the values with `and` and print `Largest: <value>` using an f-string. Do not use `max`.
#
# **Worked sample — given values:**
#
# ```python
# a = 14
# b = 31
# c = 22
# ```
#
# **Expected output:**
#
# ```text
# Largest: 31
# ```
#
# **Real version:** the real program reads three numbers with input() — see the solution.

# %%
# Compare all three values and print the largest.

# %% [markdown]
# ## Exercise 11

# %% [markdown]
# ### More Practice: Order Three Numbers
#
# A scoreboard needs three numbers in increasing order.
#
# **Specification:** Given `a`, `b`, and `c`, use only comparisons, `if` statements, and temporary-variable swaps to arrange the values from smallest to largest. Print them on one line, separated by spaces, using an f-string. Do not use loops, lists, `sorted`, `min`, or `max`.
#
# **Worked sample — given values:**
#
# ```python
# a = 19
# b = 4
# c = 11
# ```
#
# **Expected output:**
#
# ```text
# 4 11 19
# ```
#
# **Real version:** the real program reads three numbers with input() — see the solution.

# %%
# Swap out-of-order values using temporary variables, then print.

# %% [markdown]
# ## Exercise 12

# %% [markdown]
# ### More Practice: Rock-Paper-Scissors Judge
#
# Two players choose moves, and the judge announces the result.
#
# **Specification:** Given `player1` and `player2` as `"rock"`, `"paper"`, or `"scissors"`, check a tie first and print `Tie`. Otherwise use a nested `if`: branch on player 1's move, then decide whether it beats player 2's move. Print `Player 1 wins` or `Player 2 wins`.
#
# **Worked sample — given values:**
#
# ```python
# player1 = "rock"
# player2 = "scissors"
# ```
#
# **Expected output:**
#
# ```text
# Player 1 wins
# ```
#
# **Real version:** the real program reads the two players' moves with input() — see the solution.

# %%
# Check ties, then use a nested decision for the winning move.

# %% [markdown]
# ## Exercise 13

# %% [markdown]
# ### More Practice: Quadrant Finder
#
# A point on a coordinate map needs its location named.
#
# **Specification:** Given `x` and `y`, use a nested `if` to distinguish the origin, an axis, and the four quadrants. Print `(<x>, <y>) is the Origin` for `(0, 0)`, `(<x>, <y>) is on an axis` when exactly one coordinate is 0, or `(<x>, <y>) is in Quadrant I`, `II`, `III`, or `IV` using the usual signs. Use an f-string.
#
# **Worked sample — given values:**
#
# ```python
# x = -3
# y = 5
# ```
#
# **Expected output:**
#
# ```text
# (-3, 5) is in Quadrant II
# ```
#
# **Real version:** the real program reads two coordinates with input() — see the solution.

# %%
# Use nested decisions to name the point's location.

# %% [markdown]
# ## Exercise 14

# %% [markdown]
# ### More Practice: Valid Triangle
#
# Three side lengths need a validity check before drawing.
#
# **Specification:** Given positive side lengths `a`, `b`, and `c`, use `and` to require all three triangle inequalities: each pair must add to more than the third side. Print `Triangle` when all hold; otherwise print `Not a triangle`.
#
# **Worked sample — given values:**
#
# ```python
# a = 2
# b = 5
# c = 9
# ```
#
# **Expected output:**
#
# ```text
# Not a triangle
# ```
#
# **Real version:** the real program reads three side lengths with input() — see the solution.

# %%
# Check all three side-sum conditions and print one label.

# %% [markdown]
# ## Exercise 15

# %% [markdown]
# ### More Practice: Traffic Light Art
#
# A tiny signal picture changes with the light state.
#
# **Specification:** Given `state` as `"red"`, `"yellow"`, or `"green"`, use `if`/`elif`/`else` to choose three exact rows. Red prints `(R)` / `( )` / `( )`; yellow prints `( )` / `(Y)` / `( )`; green prints `( )` / `( )` / `(G)`. Save the complete picture in one named triple-quoted string, then print it last. Start the first row immediately after the opening quotes and close the quotes immediately after the last row. Use no backslashes in the art itself.
#
# **Worked sample — given values:**
#
# ```python
# state = "yellow"
# ```
#
# **Expected output:**
#
# ```text
# ( )
# (Y)
# ( )
# ```
#
# **Real version:** the real program reads a light state with input() — see the solution.

# %%
# Save one triple-quoted picture and print it.

# %% [markdown]
# ## Exercise 16

# %% [markdown]
# ### More Practice: Mood Face
#
# A score chooses a small face for the display.
#
# **Specification:** Given `score`, use `if`/`elif`/`else` to choose three exact rows. For 80 or more, print `^ ^` / ` -` / `(_)`; for 50 through 79, print `o o` / ` -` / `---`; below 50, print `- -` / ` -` / `...`. Save the complete picture in one named triple-quoted string, then print it last. Start the first row immediately after the opening quotes and close the quotes immediately after the last row. Use no backslashes or trailing spaces in the art.
#
# **Worked sample — given values:**
#
# ```python
# score = 72
# ```
#
# **Expected output:**
#
# ```text
# o o
#  -
# ---
# ```
#
# **Real version:** the real program reads a score with input() — see the solution.

# %%
# Save one triple-quoted picture and print it.

# %% [markdown]
# ## Exercise 17

# %% [markdown]
# ### Challenge 1: Triangle Logic Puzzle
#
# A triangle label depends on how many sides are equal. The most specific case must come before the broader one.
#
# **Specification:** Given `side_a`, `side_b`, and `side_c`, print `Equilateral` when all three are equal. Otherwise print `Isosceles` when any pair is equal. Print `Scalene` when no pair is equal. Use an `if`/`elif`/`else` ladder with equilateral first.
#
# **Worked sample — given values:**
#
# ```python
# side_a = 6
# side_b = 6
# side_c = 6
# ```
#
# **Expected output:**
#
# ```text
# Equilateral
# ```
#
# **Notice:** all-equal sides also satisfy every pair-equality test, so the equilateral branch must come before the isosceles branch.
#
# **Real version:** the real program reads three side lengths with input() — see the solution.

# %%
side_a = 6
side_b = 6
side_c = 6

# Check the most specific case first and print one label.

# %% [markdown]
# ## Exercise 18

# %% [markdown]
# ### Challenge 2: Leap-Year Logic Puzzle
#
# A calendar follows the full leap-year rule: divisible by 4, except centuries, except every 400th year.
#
# **Specification:** Given `year`, use exactly `(year % 4 == 0 and year % 100 != 0) or year % 400 == 0` as the condition. Print `<year> is a leap year.` when it is true; otherwise print `<year> is not a leap year.`
#
# **Worked sample — given values:**
#
# ```python
# year = 1900
# ```
#
# **Expected output:**
#
# ```text
# 1900 is not a leap year.
# ```
#
# **Real version:** the real program reads a year with input() — see the solution.

# %%
year = 1900

# Apply the full rule and print one exact sentence.

# %% [markdown]
# ## Exercise 19

# %% [markdown]
# ### Challenge 3: Closed Sign
#
# A room sign should say whether the room is closed. The saved boolean says whether the room is open.
#
# **Specification:** Given `is_open`, use `if not is_open:` to print `Closed`. Otherwise print `Open`.
#
# **Worked sample — given values:**
#
# ```python
# is_open = False
# ```
#
# **Expected output:**
#
# ```text
# Closed
# ```
#
# **Real version:** the real program reads whether a room is open with input() — see the solution.

# %%
is_open = False

# Use not in the condition and print one exact label.

# %% [markdown]
# ## Exercise 20

# %% [markdown]
# ### Challenge 4: Ticket Price
#
# A ticket booth charges by age and by weekday or weekend.
#
# **Specification:** Given `age` and `day`, use a nested `if` inside the 13–17 age branch to choose the price. Under 13 costs $6. Ages 13–17 cost $8 on weekdays or $9 on Saturday/Sunday. Ages 18 or more cost $12 on weekdays or $14 on Saturday/Sunday. Print `Ticket: $<price>` using an f-string.
#
# **Worked sample — given values:**
#
# ```python
# age = 15
# day = "Thursday"
# ```
#
# **Expected output:**
#
# ```text
# Ticket: $8
# ```
#
# **Real version:** the real program reads an age and a day name with input() — see the solution.

# %%
# Use nested decisions to select and print the ticket price.

# %% [markdown]
# ## Exercise 21

# %% [markdown]
# ### Challenge 5: Valid Clock Time
#
# A clock reading needs its hour and minute checked separately.
#
# **Specification:** Given `hour` and `minute`, use a nested `if` and chained comparisons. If `hour` is outside 0 through 23, print `Invalid hour`. Otherwise check `minute`: outside 0 through 59 prints `Invalid minute`; inside that range prints `Valid time`.
#
# **Worked sample — given values:**
#
# ```python
# hour = 23
# minute = 60
# ```
#
# **Expected output:**
#
# ```text
# Invalid minute
# ```
#
# **Real version:** the real program reads an hour and a minute with input() — see the solution.

# %%
# Check the hour, then use a nested decision for the minute.
