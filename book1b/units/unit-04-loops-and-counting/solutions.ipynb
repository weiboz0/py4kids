# %% [markdown]
# # Loops & Counting Solutions
#
# These sample answers use the exercises' fixed values so the notebook runs without stopping for keyboard input.

# %% [markdown]
# > **Note for teachers:** the `assert` lines are automatic self-checks for CI and for you — students don't need to read or understand them.

# %% [markdown]
# ## Exercise 1
#
# ### Training-Lap Counter

# %%
lap_goal = 6
laps = 0
while laps < lap_goal:
    laps = laps + 1
line = f"Count: {laps}"
print(line)
assert laps == 6
assert line == "Count: 6"

# %% [markdown]
# ## Exercise 2
#
# ### Repair the Last Number

# %%
i = 0
while i <= 5:
    print(i)
    i = i + 1

# %%
assert i == 6

# %% [markdown]
# ## Exercise 3
#
# ### Fundraiser Running Total

# %%
last_amount = 10
amount = 1
total = 0
while amount <= last_amount:
    total = total + amount
    amount = amount + 1
line = f"Sum: {total}"
print(line)
assert total == 55
assert line == "Sum: 55"

# %% [markdown]
# ## Exercise 4
#
# ### Multiples-of-Four Count

# %%
last_turn = 20
turn = 1
count = 0
while turn <= last_turn:
    if turn % 4 == 0:
        count = count + 1
    turn = turn + 1
line = f"Count: {count}"
print(line)
assert count == 5
assert line == "Count: 5"

# %% [markdown]
# ## Exercise 5
#
# ### Factorial Machine

# %%
n = 6
number = 1
product = 1
while number <= n:
    product = product * number
    number = number + 1
line = f"Product: {product}"
print(line)
assert product == 720
assert line == "Product: 720"

# %% [markdown]
# ## Exercise 6
#
# ### Digit-Sum Scanner

# %%
n = 4827
digit_total = 0
while n != 0:
    digit = n % 10
    digit_total = digit_total + digit
    n = n // 10
line = f"Digit sum: {digit_total}"
print(line)
assert n == 0
assert digit_total == 21
assert line == "Digit sum: 21"

# %% [markdown]
# ## Exercise 7
#
# ### Computed Stop: Collatz Steps

# %%
n = 6
steps = 0
while n != 1:
    if n % 2 == 0:
        n = n // 2
    else:
        n = n * 3 + 1
    steps = steps + 1
line = f"Steps: {steps}"
print(line)
assert n == 1
assert steps == 8
assert line == "Steps: 8"

# %% [markdown]
# ## Exercise 8
#
# ### Shared-Tile Size

# %%
a = 48
b = 18
while a != b:
    if a > b:
        a = a - b
    else:
        b = b - a
line = f"GCD: {a}"
print(line)
assert a == b
assert a == 6
assert line == "GCD: 6"

# %% [markdown]
# ## Exercise 9
#
# ### Score-Tier Census

# %%
score = 1
low_count = 0
middle_count = 0
high_count = 0
while score <= 10:
    if score >= 8:
        high_count = high_count + 1
    elif score >= 4:
        middle_count = middle_count + 1
    else:
        low_count = low_count + 1
    score = score + 1
line_1 = f"Low: {low_count}"
print(line_1)
assert line_1 == "Low: 3"
line_2 = f"Middle: {middle_count}"
print(line_2)
assert line_2 == "Middle: 4"
line_3 = f"High: {high_count}"
print(line_3)
assert line_3 == "High: 3"
assert low_count == 3
assert middle_count == 4
assert high_count == 3

# %% [markdown]
# ## Exercise 10
#
# ### Challenge 1: Remainder GCD

# %%
a = 252
b = 105
while b != 0:
    remainder = a % b
    a = b
    b = remainder
line = f"GCD: {a}"
print(line)
assert b == 0
assert a == 21
assert line == "GCD: 21"

# %% [markdown]
# ## Exercise 11
#
# ### Challenge 2: Probe Mission 27

# %%
n = 27
steps = 0
while True:
    if n == 1:
        break
    if n % 2 == 0:
        n = n // 2
    else:
        n = n * 3 + 1
    steps = steps + 1
line = f"Steps: {steps}"
print(line)
assert n == 1
assert steps == 111
assert line == "Steps: 111"
