# %% [markdown]
# # For & Range Practice
#
# This bank is intentionally larger than one lesson. **Core: Exercises 1–7** are the set every student completes in class. **Extra practice: Exercises 8–9** add variety if you finish early or want homework. **Challenges: Exercises 10–11** are optional stretch work; no core exercise depends on them.

# %% [markdown]
# For every exercise, use the fixed given values, follow the specification, and produce the exact output shown. Do not modify a `for` variable inside its loop body. Build table and triangle rows as strings, then print each completed row once.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### The 5050 Total
#
# A contest needs the total of every whole number from 1 through 100. This is the same result previewed in Unit 02 and rebuilt with `while` in Unit 04.
#
# **Specification:** Start `total` at 0. Use `for n in range(1, 101):` and update the running total once per pass. After the loop, print exactly `Sum: <total>`.
#
# **Worked sample — required interval:**
#
# ```text
# 1 through 100
# ```
#
# **Expected output:**
#
# ```text
# Sum: 5050
# ```

# %%
# Add 1 through 100 with for and range, then print one summary.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Stop-Bound Inspector
#
# A calibration visits every integer from 3 through 8. The report records only the final value visited.
#
# **Specification:** Start `last_seen` at 0. Use `for number in range(3, 9):` and save each visited number in `last_seen`. After the loop, print exactly `Last: <last_seen>`. Remember that the stop value is not included.
#
# **Worked sample — required interval:**
#
# ```text
# 3 through 8
# ```
#
# **Expected output:**
#
# ```text
# Last: 8
# ```

# %%
# Visit 3 through 8 and print the final visited value.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Divisible-by-Four Census
#
# A scoreboard marks every game number divisible by 4 in the first 30 games.
#
# **Specification:** Use `for number in range(1, 31):` to check 1 through 30. Add 1 to `count` only when the number is divisible by 4. After the loop, print exactly `Count: <count>`.
#
# **Worked sample — required interval:**
#
# ```text
# 1 through 30
# ```
#
# **Expected output:**
#
# ```text
# Count: 7
# ```

# %%
# Count values divisible by 4, then print one summary.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### FizzBuzz Board
#
# A number board replaces multiples of 3 with `Fizz`, multiples of 5 with `Buzz`, and multiples of both with `FizzBuzz`.
#
# **Specification:** Use a `for` loop over 1 through 15. Use one `if`/`elif`/`elif`/`else` ladder, checking divisibility by 15 first, then 3, then 5. Save exactly one result in `line` and print it once per pass.
#
# **Worked sample — required interval:**
#
# ```text
# 1 through 15
# ```
#
# **Expected output:**
#
# ```text
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# ```

# %%
# Classify and print each number from 1 through 15.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Prime-Flag Test
#
# A number is prime when no integer from 2 through one less than the number divides it exactly.
#
# **Specification:** Given an integer `n >= 2`, start `is_prime` as `True`. Loop over `range(2, n)`. When a divisor is found, set the flag to `False` and `break`. After the loop, print exactly `<n> is prime: <is_prime>`.
#
# **Worked sample — given values:**
#
# ```python
# n = 29
# ```
#
# **Expected output:**
#
# ```text
# 29 is prime: True
# ```
#
# **Notice:** if `n` were 2, `range(2, 2)` would be empty and the `True` flag would stay correct.

# %%
n = 29

# Test possible divisors with a flag and an early break.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ### Three-by-Three Times Table
#
# A study card needs one complete string per multiplication-table row.
#
# **Specification:** Given `table_size = 3`, use nested `for` loops with outer variable `row` and inner variable `col`, each visiting 1 through `table_size`. Start `row_text` as an empty string for each outer pass. Accumulate the products with one space between them, then print the completed row after the inner loop.
#
# **Worked sample — given values:**
#
# ```python
# table_size = 3
# ```
#
# **Expected output:**
#
# ```text
# 1 2 3
# 2 4 6
# 3 6 9
# ```

# %%
table_size = 3

# Build each row as a string, then print it once.

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# ### Nested Classification Count
#
# A game master wants numbers that pass two tests: they must be even, and then they must also be divisible by 3.
#
# **Specification:** Use `for number in range(1, 13):`. Inside the loop, first use `if number % 2 == 0:`. Inside that `if`, place another `if` that tests divisibility by 3 and adds 1 to `count`. After the loop, print exactly `Count: <count>`. This must be an `if` inside an `if` inside the `for`.
#
# **Worked sample — required interval:**
#
# ```text
# 1 through 12
# ```
#
# **Expected output:**
#
# ```text
# Count: 2
# ```

# %%
# Nest the two tests and count numbers that pass both.

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# ### Growing Signal Triangle
#
# A signal display has one star in row 1, two in row 2, and so on through the chosen height.
#
# **Specification:** Given `height = 5`, use nested `for` loops named `row` and `col`. For each row, start `row_text` as an empty string. Add one `"*"` per inner pass, then print the completed row once. Do not use string repetition.
#
# **Worked sample — given values:**
#
# ```python
# height = 5
# ```
#
# **Expected output:**
#
# ```text
# *
# **
# ***
# ****
# *****
# ```

# %%
height = 5

# Accumulate and print one row at a time.

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# ### Factorial over a Range
#
# A combination counter multiplies the integers from 1 through a small number.
#
# **Specification:** Given an integer `n` from 1 through 10, initialize `product` to 1. Use `for number in range(1, n + 1):` to update the product. After the loop, print exactly `Product: <product>`.
#
# **Worked sample — given values:**
#
# ```python
# n = 7
# ```
#
# **Expected output:**
#
# ```text
# Product: 5040
# ```

# %%
n = 7

# Multiply 1 through n, then print one summary.

# %% [markdown]
# ## Exercise 10

# %% [markdown]
# ### Challenge 1: Step-Range Total
#
# A shortcut range can advance by 2, visiting only the even values.
#
# **Specification:** Use the Challenge-only three-argument form `range(2, 21, 2)` to visit the even integers from 2 through 20. Add them to a running total, then print exactly `Sum: <total>`.
#
# **Worked sample — required values:**
#
# ```text
# 2, 4, 6, ..., 20
# ```
#
# **Expected output:**
#
# ```text
# Sum: 110
# ```

# %%
# Use the three-argument range and print one summary.

# %% [markdown]
# ## Exercise 11

# %% [markdown]
# ### Challenge 2: Count the Primes
#
# A number lab needs the count of primes from 2 through 20. Each candidate needs its own flag and divisor search.
#
# **Specification:** Use an outer `for candidate in range(2, 21):`. Set `is_prime = True` for each candidate. In an inner loop over possible divisors, set the flag to `False` and `break` when one divides evenly. After the inner loop, add 1 to `prime_count` only when the flag is still true. Print exactly `Count: <prime_count>` after the outer loop.
#
# **Worked sample — required interval:**
#
# ```text
# 2 through 20
# ```
#
# **Expected output:**
#
# ```text
# Count: 8
# ```

# %%
# Test each candidate, count the primes, and print one summary.
