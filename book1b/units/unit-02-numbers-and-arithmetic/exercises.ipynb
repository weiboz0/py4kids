# %% [markdown]
# # Numbers & Arithmetic Practice
#
# **Core: Exercises 1–11** are the in-class path. **More Practice: Exercises 12–18** give extra reps. **Challenges: Exercises 19–23** are optional stretch work; no core exercise depends on them.

# %% [markdown]
# For every exercise, follow the specification and produce the exact output shown. Run your cell and compare every capital letter, space, punctuation mark, and number with the worked sample. Write the lines directly.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Supply Total
#
# An art table has several packs with the same number of pencils in each pack. It needs the total number of pencils.
#
# **Specification:** Given `packs` and `pencils_per_pack`, multiply them and print exactly `Total pencils: <total>`.
#
# **Worked sample — given values:**
#
# ```python
# packs = 6
# pencils_per_pack = 8
# ```
#
# **Expected output:**
#
# ```text
# Total pencils: 48
# ```
#
# **Real version:** the real program reads the pack count and pencils per pack with input() — see the solution.

# %%
packs = 6
pencils_per_pack = 8

# Calculate and print the exact total.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Trip Time
#
# A trip schedule stores one duration in minutes but displays complete hours and leftover minutes.
#
# **Specification:** Given the non-negative integer `total_minutes`, use `//` and `%` to print exactly `<hours> hours <minutes> minutes`.
#
# **Worked sample — given values:**
#
# ```python
# total_minutes = 185
# ```
#
# **Expected output:**
#
# ```text
# 3 hours 5 minutes
# ```
#
# **Real version:** the real program reads the trip length in minutes with input() — see the solution.

# %%
total_minutes = 185

# Split the time and print the exact schedule line.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Equal Share
#
# Four teammates share a given number of meters of ribbon equally. The result should use regular division.
#
# **Specification:** Given `ribbon_meters` and `teammates`, use `/` to print exactly `Meters each: <share>`. Show Python's exact float output.
#
# **Worked sample — given values:**
#
# ```python
# ribbon_meters = 14
# teammates = 4
# ```
#
# **Expected output:**
#
# ```text
# Meters each: 3.5
# ```
#
# **Real version:** the real program reads the ribbon length and number of teammates with input() — see the solution.

# %%
ribbon_meters = 14
teammates = 4

# Divide and print the exact float output.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Next-Year Age
#
# A saved age arrived as text. It must become a number before Python can add one.
#
# **Specification:** Given `age_text`, convert it with `int()`, add 1, and print exactly `Next year: <age>`.
#
# **Worked sample — given values:**
#
# ```python
# age_text = "12"
# ```
#
# **Expected output:**
#
# ```text
# Next year: 13
# ```
#
# **Real version:** the real program reads the age as text with input() — see the solution.

# %%
age_text = "12"

# Convert the quoted digits, calculate, and print.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Compare Two Scores
#
# A practice board needs direct `True` or `False` answers to two questions: whether the first score is higher, and whether it is at least as high.
#
# **Specification:** Given `first_score` and `second_score`, first compare them with `>` and print the boolean result directly. Then compare them with `>=` and print that boolean result directly.
#
# **Worked sample — given values:**
#
# ```python
# first_score = 18
# second_score = 15
# ```
#
# **Expected output:**
#
# ```text
# True
# True
# ```
#
# **Real version:** the real program reads the two scores with input() — see the solution.

# %%
first_score = 18
second_score = 15

# Print both comparison results directly.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ### Two-Digit Report
#
# A display separates the tens and ones places of a two-digit number.
#
# **Specification:** Given `number`, which is an integer from 10 through 99, use `//` and `%` to print `Tens: <tens>` and `Ones: <ones>` on separate lines.
#
# **Worked sample — given values:**
#
# ```python
# number = 73
# ```
#
# **Expected output:**
#
# ```text
# Tens: 7
# Ones: 3
# ```
#
# **Real version:** the real program reads the two-digit number with input() — see the solution.

# %%
number = 73

# Split the two-digit number and print both labels.

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# ### Repair the Age Label
#
# An age label stops with a `TypeError` because it tries to join text and an integer with `+`.
#
# **Specification:** Repair the broken instruction by converting `age` with `str()` so it prints exactly `Age: 12`. Put the repaired instruction in the empty cell.
#
# **Worked sample — broken instruction:**
#
# ```python
# age = 12
# print("Age: " + age)
# ```
#
# **Expected output after the repair:**
#
# ```text
# Age: 12
# ```
#
# **No real version:** this exercise fixes code rather than reading input.

# %%
age = 12
print("Age: " + age)

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# ### Price Calculator
#
# A shop needs the cost of two items at the same price. The given price is saved as text, as it would be when read from input.
#
# **Specification:** Given `price_text`, convert it with `float()`, multiply the number by 2, and print exactly `Two cost: <total>`.
#
# **Worked sample — given values:**
#
# ```python
# price_text = "3.5"
# ```
#
# **Expected output:**
#
# ```text
# Two cost: 7.0
# ```
#
# **Real version:** the real program reads the price with input() — see the solution.

# %%
price_text = "3.5"

# Convert the fixed text, calculate, and print.

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# ### Coin Change
#
# A coin counter trades cents for the fewest quarters, then dimes, nickels, and pennies.
#
# **Specification:** Given non-negative `cents`, use `//` and `%` to print `Quarters: <count>`, `Dimes: <count>`, `Nickels: <count>`, and `Pennies: <count>` on separate lines. Add a purpose comment explaining the coin calculation.
#
# **Worked sample — given values:**
#
# ```python
# cents = 83
# ```
#
# **Expected output:**
#
# ```text
# Quarters: 3
# Dimes: 0
# Nickels: 1
# Pennies: 3
# ```
#
# **Real version:** the real program reads the amount of cents with input() — see the solution.

# %%
# Explain the purpose of your coin calculation.
# Calculate and print each coin count.

# %% [markdown]
# ## Exercise 10

# %% [markdown]
# ### Seconds Breakdown
#
# A timer stores a duration in seconds and needs a readable breakdown.
#
# **Specification:** Given non-negative `seconds`, use `//` and `%` to print complete hours, remaining minutes, and remaining seconds on three labeled lines. Add a purpose comment explaining the breakdown.
#
# **Worked sample — given values:**
#
# ```python
# seconds = 4000
# ```
#
# **Expected output:**
#
# ```text
# Hours: 1
# Minutes: 6
# Seconds: 40
# ```
#
# **Real version:** the real program reads the duration in seconds with input() — see the solution.

# %%
# Explain the purpose of your time breakdown.
# Calculate and print the three labeled parts.

# %% [markdown]
# ## Exercise 11

# %% [markdown]
# ### Boolean Report
#
# A scoreboard needs three direct yes-or-no checks for one score.
#
# **Specification:** Given `score`, print the boolean results of `score >= 60`, `score == 100`, and `score != 0`, in that order, one per line.
#
# **Worked sample — given values:**
#
# ```python
# score = 66
# ```
#
# **Expected output:**
#
# ```text
# True
# False
# True
# ```
#
# **Real version:** the real program reads the score with input() — see the solution.

# %%
# Print the three boolean results directly.

# %% [markdown]
# ## Exercise 12

# %% [markdown]
# ### More Practice: Three-Digit Sum
#
# A place-value puzzle adds the three digits of a number.
#
# **Specification:** Given a three-digit integer `number`, separate its digits with `//` and `%`, then print their sum.
#
# **Worked sample — given values:**
#
# ```python
# number = 468
# ```
#
# **Expected output:**
#
# ```text
# 18
# ```
#
# **Real version:** the real program reads the three-digit number with input() — see the solution.

# %%
# Split the digits and print their sum.

# %% [markdown]
# ## Exercise 13

# %% [markdown]
# ### More Practice: Power Pair
#
# A square and a cube both grow from the same side length.
#
# **Specification:** Given `side`, use `**` to print `Square: <value>` and `Cube: <value>` on separate lines.
#
# **Worked sample — given values:**
#
# ```python
# side = 7
# ```
#
# **Expected output:**
#
# ```text
# Square: 49
# Cube: 343
# ```
#
# **Real version:** the real program reads the side length with input() — see the solution.

# %%
# Calculate and print the square and cube.

# %% [markdown]
# ## Exercise 14

# %% [markdown]
# ### More Practice: Clock Arithmetic
#
# A twelve-hour clock wraps around after 12 rather than showing hour 0.
#
# **Specification:** Given an `hour` from 1 through 12 and non-negative `added` hours, calculate `(hour - 1 + added) % 12 + 1` and print `<result> o'clock`.
#
# **Worked sample — given values:**
#
# ```python
# hour = 10
# added = 5
# ```
#
# **Expected output:**
#
# ```text
# 3 o'clock
# ```
#
# **Real version:** the real program reads the starting hour and added hours with input() — see the solution.

# %%
# Use the given wraparound formula and print the new hour.

# %% [markdown]
# ## Exercise 15

# %% [markdown]
# ### More Practice: Progress Bar
#
# A ten-slot progress bar fills one slot per ten points.
#
# **Specification:** Given a `score` from 0 through 100, calculate `filled = score // 10`, then build and print `"#" * filled + "-" * (10 - filled)`.
#
# **Worked sample — given values:**
#
# ```python
# score = 38
# ```
#
# **Expected output:**
#
# ```text
# ###-------
# ```
#
# **Real version:** the real program reads the score with input() — see the solution.

# %%
# Build the ten-slot bar and print it.

# %% [markdown]
# ## Exercise 16

# %% [markdown]
# ### More Practice: Box Banner
#
# A lab sign frames a fixed-width title.
#
# **Specification:** Given `title = "STAR LAB"` (8 characters), build the three-line picture using `"-" * 10` for the top and bottom. Save each row in a named string variable and print the exact rows.
#
# **Worked sample — given values:**
#
# ```python
# title = "STAR LAB"
# ```
#
# **Expected output:**
#
# ```text
# +----------+
# | STAR LAB |
# +----------+
# ```
#
# **Real version:** the real program reads the title with input() — see the solution.

# %%
# Build each row as a named string and print the picture.

# %% [markdown]
# ## Exercise 17

# %% [markdown]
# ### More Practice: Precedence Predictions
#
# An expression can change its value when operators group differently.
#
# **Specification:** Without running the expressions first, predict the values of `6 + 4 * 2`, `(6 + 4) * 2`, `20 // 3 % 4`, `2 ** 3 * 2`, and `7 + 1 > 2 * 4`, in that order. Write the five predictions as comments, then check them with Python.
#
# **Worked sample — given values:**
#
# ```python
# 6 + 4 * 2
# (6 + 4) * 2
# 20 // 3 % 4
# 2 ** 3 * 2
# 7 + 1 > 2 * 4
# ```
#
# **Expected output:**
#
# ```text
# 14
# 20
# 2
# 16
# False
# ```
#
# **No real version:** this exercise traces code rather than reading input.

# %%
# Prediction 1:
# Prediction 2:
# Prediction 3:
# Prediction 4:
# Prediction 5:
# Then check each expression with Python.

# %% [markdown]
# ## Exercise 18

# %% [markdown]
# ### More Practice: Read the ValueError
#
# A conversion crashes when decimal text is passed to `int()`.
#
# **Specification:** Read the broken `int("6.25")` instruction, then repair it with `float()` and print the resulting number. Put the repaired instruction in the starter cell.
#
# **Worked sample — given values:**
#
# ```python
# print(int("6.25"))
# ```
#
# **Expected output:**
#
# ```text
# 6.25
# ```
#
# **No real version:** this exercise fixes code rather than reading input.

# %%
# Replace the broken conversion with float() and print its value.

# %% [markdown]
# ## Exercise 19

# %% [markdown]
# ### Challenge 1: Reverse Two Digits
#
# A number puzzle reverses the two places of a given two-digit number.
#
# **Specification:** Given `number`, which is an integer from 10 through 99, separate its tens and ones digits. Build the reversed integer with arithmetic and print exactly `Reversed: <number>`.
#
# **Worked sample — given values:**
#
# ```python
# number = 42
# ```
#
# **Expected output:**
#
# ```text
# Reversed: 24
# ```
#
# **Real version:** the real program reads the two-digit number with input() — see the solution.

# %%
number = 42

# Split, rebuild in reverse order, and print.

# %% [markdown]
# ## Exercise 20

# %% [markdown]
# ### Challenge 2: Three-Digit Places
#
# A place-value display separates every digit of a three-digit number.
#
# **Specification:** Given `number`, which is an integer from 100 through 999, use arithmetic with non-negative operands to print `Hundreds: <digit>`, `Tens: <digit>`, and `Ones: <digit>` on separate lines.
#
# **Worked sample — given values:**
#
# ```python
# number = 582
# ```
#
# **Expected output:**
#
# ```text
# Hundreds: 5
# Tens: 8
# Ones: 2
# ```
#
# **Real version:** the real program reads the three-digit number with input() — see the solution.

# %%
number = 582

# Separate and print all three digits.

# %% [markdown]
# ## Exercise 21

# %% [markdown]
# ### Challenge 3: The 1089 Trick
#
# A three-digit number can hide a surprising constant.
#
# **Specification:** Given a three-digit `number` whose hundreds digit is greater than its ones digit, reverse its digits as a three-digit place-value calculation. Subtract the smaller number from the larger. Reverse the difference as **three digits** using `// 100`, `// 10 % 10`, and `% 10`; then print the sum of the difference and its reverse. A difference of 99 must be treated as `099`, whose reverse is `990`.
#
# **Worked sample — given values:**
#
# ```python
# number = 841
# ```
#
# **Expected output:**
#
# ```text
# 1089
# ```
#
# **Real version:** the real program reads the three-digit number with input() — see the solution.

# %%
# Reverse, subtract, reverse the three-digit difference, then print the sum.

# %% [markdown]
# ## Exercise 22

# %% [markdown]
# ### Challenge 4: Receipt Line
#
# A receipt adds two prices and always shows cents.
#
# **Specification:** Given `first_price` and `second_price`, add them and print `Total: $<amount>` with exactly two digits after the decimal point using `:.2f`.
#
# **Worked sample — given values:**
#
# ```python
# first_price = 2.4
# second_price = 3.15
# ```
#
# **Expected output:**
#
# ```text
# Total: $5.55
# ```
#
# **Real version:** the real program reads the two prices with input() — see the solution.

# %%
# Add the two prices and print the formatted total.

# %% [markdown]
# ## Exercise 23

# %% [markdown]
# ### Challenge 5: Framed Title
#
# A team poster surrounds a known-width title with stars.
#
# **Specification:** Given `title = "GO TEAM"` (7 characters) and `width = 11`, build a top and bottom row of `"*" * width` and a middle row `* GO TEAM *`. Save each row in a named string variable and print the exact three-line picture.
#
# **Worked sample — given values:**
#
# ```python
# title = "GO TEAM"
# width = 11
# ```
#
# **Expected output:**
#
# ```text
# ***********
# * GO TEAM *
# ***********
# ```
#
# **Real version:** the real program reads the title and width with input() — see the solution.

# %%
# Build each row as a named string and print the picture.
