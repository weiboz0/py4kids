# %% [markdown]
# # Turtle Geometry Solutions
#
# Each runnable drawing lives in its named asset. The code cells check the geometry without opening a turtle window.

# %% [markdown]
# ## Exercise 1
#
# ### Courtyard Square
#
# **Solution asset (`assets/solutions_ex1.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Set up the four-sided courtyard outline.
# n = 4
# side = 62
# angle = 360 / n
# turtle.pencolor("royalblue")
#
# # Each trip traces one courtyard edge and aims the turtle toward the next corner.
# for corner in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex1.py")
trace = state()

assert trace["moves"] == 4
assert trace["pen_down_moves"] == 4
assert trace["total_heading_change"] == 360
assert -1e-6 < trace["x"] < 1e-6
assert -1e-6 < trace["y"] < 1e-6

# %% [markdown]
# ## Exercise 2
#
# ### Trail-Sign Triangle
#
# **Solution asset (`assets/solutions_ex2.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Set up the triangular trail-sign border.
# n = 3
# side = 74
# angle = 360 / n
# turtle.pencolor("forestgreen")
#
# # The turtle uses the 120-degree outside angle at each corner.
# for corner in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex2.py")
trace = state()

assert trace["moves"] == 3
assert trace["pen_down_moves"] == 3
assert trace["total_heading_change"] == 360
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 3
#
# ### Festival Pentagon
#
# **Solution asset (`assets/solutions_ex3.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Set up an orchid pentagon with a thicker outline.
# n = 5
# side = 68
# angle = 360 / n
# turtle.pencolor("orchid")
# turtle.pensize(4)
#
# # Draw the five equal sides of the pentagon.
# for side_number in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex3.py")
trace = state()

assert trace["moves"] == 5
assert trace["pen_down_moves"] == 5
assert trace["total_heading_change"] == 360
assert -1e-6 < trace["y"] < 1e-6

# %% [markdown]
# ## Exercise 4
#
# ### Decimal-Turn Heptagon
#
# **Solution asset (`assets/solutions_ex4.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Set up the seven-sided game token.
# n = 7
# side = 57
# angle = 360 / n
# turtle.pencolor("darkorange")
# print(angle)
#
# # angle is a float, and all seven turns total 360 degrees.
# for corner in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex4.py")
trace = state()

assert trace["moves"] == 7
assert trace["pen_down_moves"] == 7
assert -1e-6 < trace["total_heading_change"] - 360 < 1e-6
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 5
#
# ### Move, Then Mark
#
# **Solution asset (`assets/solutions_ex5.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Travel to the map symbol's starting point without drawing a road.
# turtle.penup()
# turtle.forward(39)
# turtle.pendown()
#
# # Set up the octagonal map symbol.
# n = 8
# side = 44
# angle = 360 / n
# turtle.pencolor("crimson")
#
# # Draw eight equal sides from the new starting point.
# for corner in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex5.py")
trace = state()

assert trace["moves"] == 9
assert trace["pen_down_moves"] == 8
assert trace["draw_start_x"] == 39
assert -1e-6 < trace["x"] - 39 < 1e-6

# %% [markdown]
# ## Exercise 6
#
# ### Nine-Hexagon Wheel
#
# **Solution asset (`assets/solutions_ex6.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Set up one hexagon and the nine-shape wheel.
# n = 6
# side = 41
# angle = 360 / n
# shape_count = 9
# turn_between_shapes = 360 / shape_count
# turtle.pencolor("turquoise")
#
# # The outer loop repeats whole hexagons around the wheel.
# for shape in range(shape_count):
#     # The inner loop finishes all six sides of one hexagon.
#     for corner in range(n):
#         turtle.forward(side)
#         turtle.left(angle)
#     turtle.left(turn_between_shapes)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex6.py")
trace = state()

assert trace["moves"] == 54
assert trace["pen_down_moves"] == 54
assert trace["total_heading_change"] == 3600
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 7
#
# ### Growing Radar Spiral
#
# **Solution asset (`assets/solutions_ex7.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # turtle-check: open-path
# # Set up an outward-growing radar spiral.
# side = 11
# step = 6
# move_count = 14
# turtle.pencolor("maroon")
#
# # Each move grows by the same amount, so this path stays open.
# for side_number in range(move_count):
#     turtle.forward(side)
#     turtle.left(92)
#     side = side + step
#
# print(side)
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex7.py")
trace = state()

assert trace["moves"] == 14
assert trace["pen_down_moves"] == 14
assert trace["total_heading_change"] == 1288
assert trace["x"] != 0

# %% [markdown]
# ## Exercise 8
#
# ### Row of Squares
#
# **Solution asset (`assets/solutions_ex8.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# squares = 4
# side = 40
# travel = 60
#
# # Draw each square, then travel to the next starting point without ink.
# for square in range(squares):
#     for corner in range(4):
#         turtle.forward(side)
#         turtle.left(90)
#     turtle.penup()
#     turtle.forward(travel)
#     turtle.pendown()
#
# # Four travels put the turtle 240 steps away; return to the start.
# turtle.penup()
# turtle.backward(240)
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex8.py")
trace = state()

assert trace["moves"] == 21
assert trace["pen_down_moves"] == 16
assert trace["total_heading_change"] == 1440
assert -1e-6 < trace["x"] < 1e-6
assert -1e-6 < trace["y"] < 1e-6

# %% [markdown]
# ## Exercise 9
#
# ### Dashed Line
#
# **Solution asset (`assets/solutions_ex9.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # turtle-check: open-path
# segments = 24
# step = 10
# dashes = 0
#
# for i in range(segments):
#     if i % 2 == 0:
#         turtle.pendown()
#         turtle.forward(step)
#         dashes = dashes + 1
#     else:
#         turtle.penup()
#         turtle.forward(step)
#
# print(f"Dashes: {dashes}")
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex9.py")
trace = state()

assert trace["moves"] == 24
assert trace["pen_down_moves"] == 12
assert trace["x"] == 240
assert trace["y"] == 0

# %% [markdown]
# ## Exercise 10
#
# ### More Practice: Color-Alternating Ring
#
# **Solution asset (`assets/solutions_ex10.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# squares = 8
# side = 40
# turned = 0
# count = 0
#
# for i in range(squares):
#     if i % 3 == 0:
#         turtle.pencolor("red")
#     elif i % 3 == 1:
#         turtle.pencolor("blue")
#     else:
#         turtle.pencolor("green")
#     for corner in range(4):
#         turtle.forward(side)
#         turtle.left(90)
#     turtle.left(45)
#     turned = turned + 45
#     count = count + 1
#
# print(f"Turned: {turned}")
# print(f"Squares: {count}")
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex10.py")
trace = state()

assert trace["moves"] == 32
assert trace["pen_down_moves"] == 32
assert trace["total_heading_change"] == 3240
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 11
#
# ### More Practice: Growing Squares
#
# **Solution asset (`assets/solutions_ex11.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# side = 20
# drawn = 0
#
# for square in range(5):
#     for corner in range(4):
#         turtle.forward(side)
#         turtle.left(90)
#     side = side + 20
#     drawn = drawn + 1
#
# print(f"Squares: {drawn}")
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex11.py")
trace = state()

assert trace["moves"] == 20
assert trace["pen_down_moves"] == 20
assert trace["total_heading_change"] == 1800
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 12
#
# ### More Practice: Seven-Point Star
#
# **Solution asset (`assets/solutions_ex12.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# points = 7
# side = 90
#
# # Keep the true fractional turn so all seven strokes close the star.
# for point in range(points):
#     turtle.forward(side)
#     turtle.left(3 * 360 / 7)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex12.py")
trace = state()

assert trace["moves"] == 7
assert trace["pen_down_moves"] == 7
assert -1e-6 < trace["total_heading_change"] - 1080 < 1e-6
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 13
#
# ### More Practice: Fix the Misspelled Command
#
# **Solution asset (`assets/solutions_ex13.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # The command is forward, with the r after the first o.
# side = 50
# for corner in range(4):
#     turtle.forward(side)
#     turtle.left(90)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex13.py")
trace = state()

assert trace["moves"] == 4
assert trace["pen_down_moves"] == 4
assert trace["total_heading_change"] == 360
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 14
#
# ### More Practice: Fix the Missing Import
#
# **Solution asset (`assets/solutions_ex14.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools before calling them.
# import turtle
#
# side = 70
# for corner in range(3):
#     turtle.forward(side)
#     turtle.left(360 / 3)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex14.py")
trace = state()

assert trace["moves"] == 3
assert trace["pen_down_moves"] == 3
assert trace["total_heading_change"] == 360
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 15
#
# ### More Practice: Fix the Indentation
#
# **Solution asset (`assets/solutions_ex15.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# side = 60
# n = 5
#
# # Both drawing commands belong inside the loop body.
# for corner in range(n):
#     turtle.forward(side)
#     turtle.left(360 / n)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex15.py")
trace = state()

assert trace["moves"] == 5
assert trace["pen_down_moves"] == 5
assert trace["total_heading_change"] == 360
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 16
#
# ### Challenge 1: Five-Point Star
#
# **Solution asset (`assets/solutions_ex16.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Set up a five-point stage logo.
# n = 5
# side = 96
# angle = 720 / n
# turtle.pencolor("goldenrod")
# turtle.pensize(3)
#
# # A star crosses its center, so its turns make two full 360-degree turns.
# for point in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex16.py")
trace = state()

assert trace["moves"] == 5
assert trace["pen_down_moves"] == 5
assert trace["total_heading_change"] == 720
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 17
#
# ### Challenge 2: The Eight-Degree Gap
#
# **Solution asset (`assets/solutions_ex17.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# # Use the honest decimal angle for a closed eleven-sided comparison shape.
# n = 11
# side = 34
# angle = 360 / n
# turtle.pencolor("magenta")
#
# # Eleven equal decimal turns complete the regular hendecagon.
# for corner in range(n):
#     turtle.forward(side)
#     turtle.left(angle)
#
# turtle.done()
# ```
#
# The correct program uses true division, so its angle is `360 / 11`, about 32.727 degrees, and the shape closes. The shortcut gives `360 // 11 == 32`, and `11 * 32 == 352`, so it leaves an 8-degree gap. The turtle's direction is off and the outline does not close.

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex17.py")
trace = state()

assert trace["moves"] == 11
assert trace["pen_down_moves"] == 11
assert -1e-6 < trace["total_heading_change"] - 360 < 1e-6
assert -1e-6 < trace["x"] < 1e-6

# %% [markdown]
# ## Exercise 18
#
# ### Challenge 3: Grid of Squares
#
# **Solution asset (`assets/solutions_ex18.py`)**
#
# ```python
# # Bring in Python's turtle drawing tools.
# import turtle
#
# rows = 3
# columns = 3
# side = 30
# travel = 45
# squares = 0
#
# for row in range(rows):
#     for column in range(columns):
#         for corner in range(4):
#             turtle.forward(side)
#             turtle.left(90)
#         squares = squares + 1
#         turtle.penup()
#         turtle.forward(travel)
#         turtle.pendown()
#     # Return to the row start before moving up to the next row.
#     turtle.penup()
#     turtle.backward(columns * travel)
#     if row < rows - 1:
#         turtle.left(90)
#         turtle.forward(travel)
#         turtle.right(90)
#     else:
#         turtle.left(90)
#         turtle.backward((rows - 1) * travel)
#         turtle.right(90)
#     turtle.pendown()
#
# print(f"Squares: {squares}")
# turtle.done()
# ```

# %%
from runpy import run_path
import sys
from tools.fake_turtle import reset, state

reset()
from tools import fake_turtle
sys.modules["turtle"] = fake_turtle
run_path("assets/solutions_ex18.py")
trace = state()

assert trace["moves"] == 51
assert trace["pen_down_moves"] == 36
assert trace["total_heading_change"] == 3240
assert -1e-6 < trace["x"] < 1e-6
assert -1e-6 < trace["y"] < 1e-6
