# %% [markdown]
# # Strings Practice
#
# Core work is Exercises 1–7. Exercises 8–9 are optional Challenges. Each exercise asks you to define a function that meets a specification and to try every worked sample call.

# %% [markdown]
# Keep each exact function name and parameter. Return the promised value unless the specification says to print a report. Add a short purpose comment and use meaningful local names. The worked calls and expected outputs are text to guide your own checks.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Badge Line
#
# A club badge needs two initials, a three-character code piece, and the code length.
#
# **Specification:** Define `badge_line(first, last, code)`. Use position 0 from `first` and `last`. Use the slice `code[2:5]`. Return one string in the shape `initials | piece | length`. Build it with string concatenation, and use `str(len(code))` for the final part.
#
# **Worked sample calls:**
#
# ```text
# badge_line("Mira", "Stone", "AX742Q") -> "MS | 742 | 6"
# badge_line("Leo", "Park", "ZZcat9") -> "LP | cat | 6"
# badge_line("Nia", "Young", "12SUN") -> "NY | SUN | 5"
# ```

# %%
# Define badge_line(first, last, code), then check all three examples.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Clean a Route Label
#
# A route board receives labels with spaces at the ends and underscores between words.
#
# **Specification:** Define `clean_route(text)`. Remove spaces from the ends, replace each underscore with a single space, and return the result in uppercase. Use only the taught string methods.
#
# **Worked sample calls:**
#
# ```text
# clean_route("  north_gate " ) -> "NORTH GATE"
# clean_route("moon_base") -> "MOON BASE"
# clean_route("  red_fox_2  " ) -> "RED FOX 2"
# ```

# %%
# Define clean_route(text), then check all three examples.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Palindrome Gate
#
# A word gate opens when its text reads the same from both ends.
#
# **Specification:** Define `is_palindrome(text)`. Make a lowercase string with spaces replaced by empty text. Use exactly `for i in range(len(cleaned) // 2)`. Compare `cleaned[i]` with `cleaned[len(cleaned) - 1 - i]`. Return `False` inside the loop on a mismatch, and return `True` after the loop.
#
# **Worked sample calls:**
#
# ```text
# is_palindrome("Taco cat") -> True
# is_palindrome("python") -> False
# is_palindrome("Level") -> True
# ```

# %%
# Define is_palindrome(text) with the specified half-walk.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Classify a Character
#
# A message checker labels each character as a vowel, consonant, or other character.
#
# **Specification:** Define `classify_char(ch)`. Lowercase `ch`. If it is in `"aeiou"`, return `"vowel"`. Elif it is in `"abcdefghijklmnopqrstuvwxyz"`, return `"consonant"`. Else return `"other"`.
#
# **Worked sample calls:**
#
# ```text
# classify_char("U") -> "vowel"
# classify_char("m") -> "consonant"
# classify_char("7") -> "other"
# ```

# %%
# Define classify_char(ch) with if, elif, and else.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Mask the Vowels
#
# A puzzle display hides vowels but leaves every other character unchanged.
#
# **Specification:** Define `mask_vowels(text)`. Start a new string as empty. Visit each character in `text`. If its lowercase form is in `"aeiou"`, add `"*"` to the new string; else add the original character. Return the completed new string. Do not change the original string.
#
# **Worked sample calls:**
#
# ```text
# mask_vowels("Rocket") -> "R*ck*t"
# mask_vowels("SKY") -> "SKY"
# mask_vowels("A-OK!") -> "*-*K!"
# ```

# %%
# Define mask_vowels(text) by building a new string one character at a time.

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# ### First Matching Position
#
# A decoder needs the first position where a chosen character appears.
#
# **Specification:** Define `position(text, ch)`. Loop through `range(len(text))`. Return `i` inside the loop at the first position where `text[i] == ch`. Return `-1` after the loop when no position matched. The return value is an integer.
#
# **Worked sample calls:**
#
# ```text
# position("banana", "n") -> 2
# position("cocoa", "o") -> 1
# position("planet", "x") -> -1
# ```

# %%
# Define position(text, ch), then check every example.

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# ### Alphabet Scan Report
#
# A word lab needs a printed table showing the total for every lowercase alphabet letter.
#
# **Specification:** First define `count_char(text, ch)`. Start an integer counter at 0, visit every character, add 1 when the character equals `ch`, and return the counter. Then define `print_alphabet_scan(text)`. Lowercase `text`, print the heading `letter | total`, loop through `"abcdefghijklmnopqrstuvwxyz"`, call `count_char` for each letter, and print each row with an f-string. Do not return the table.
#
# **Worked sample calls:**
#
# ```text
# count_char("pepper", "p") -> 3
# count_char("pepper", "z") -> 0
#
# print_alphabet_scan("Bee") ->
# letter | total
# a | 0
# b | 1
# c | 0
# d | 0
# e | 2
# f | 0
# g | 0
# h | 0
# i | 0
# j | 0
# k | 0
# l | 0
# m | 0
# n | 0
# o | 0
# p | 0
# q | 0
# r | 0
# s | 0
# t | 0
# u | 0
# v | 0
# w | 0
# x | 0
# y | 0
# z | 0
# ```

# %%
# Define count_char(text, ch), then define print_alphabet_scan(text).

# %% [markdown]
# ## Exercise 8 — Challenge

# %% [markdown]
# ### Challenge 1: Alternating Case
#
# A sign painter alternates uppercase and lowercase characters by position.
#
# **Specification:** Define `alternating_case(text)`. Start an empty result string. Loop through `range(len(text))`. Add `text[i].upper()` when `i % 2 == 0`; else add `text[i].lower()`. Return the completed string. Spaces and punctuation stay in their positions.
#
# **Worked sample calls:**
#
# ```text
# alternating_case("python") -> "PyThOn"
# alternating_case("moon base") -> "MoOn bAsE"
# alternating_case("A1b2!") -> "A1B2!"
# ```

# %%
# Define alternating_case(text) by building one new string.

# %% [markdown]
# ## Exercise 9 — Challenge

# %% [markdown]
# ### Challenge 2: Caesar Shift
#
# A puzzle transmitter shifts letters forward and wraps around the alphabet.
#
# **Specification:** First define `position(alphabet, ch)` with the same left-to-right search as Exercise 6: return `i` inside the loop for a match and `-1` after the loop. Then define `shift(message, k)` for `k >= 0`. Set `alphabet` to `"abcdefghijklmnopqrstuvwxyz"`, lowercase the message, and build a new string character by character. For each character, call `position(alphabet, ch)`. If it returns `-1`, add the unchanged character. Else use `(pos + k) % 26` and alphabet indexing to add the shifted letter. Return the new string.
#
# **Worked sample calls:**
#
# ```text
# position("abcdefghijklmnopqrstuvwxyz", "q") -> 16
# shift("Code 9!", 2) -> "eqfg 9!"
# shift("XYZ", 3) -> "abc"
# shift("stay", 0) -> "stay"
# ```

# %%
# Define position(alphabet, ch) first, then define shift(message, k).
