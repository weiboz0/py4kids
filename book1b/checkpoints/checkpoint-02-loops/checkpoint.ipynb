# %% [markdown]
# # Checkpoint 02: Loops
#
# Complete all seven questions. Questions 1–2 recap decisions and arithmetic. Questions 3–7 assess loop counters, a computed sentinel with `break`, a running total, count by condition, and nested table building. Use only the fixed given values and produce the exact output shown.

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Ordered Battery Ladder
#
# A rover assigns a battery label using the first threshold that matches.
#
# **Specification:** Given `charge`, use exactly one `if`/`elif`/`elif`/`else` ladder. Check `charge >= 80` for `Full` first, `charge >= 50` for `Ready` next, and `charge >= 20` for `Low` next; otherwise print `Recharge`.
#
# **Worked sample — given values:**
#
# ```python
# charge = 67
# ```
#
# **Expected output:**
#
# ```text
# Ready
# ```

# %%
charge = 67

# Check the thresholds from highest to lowest and print one label.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Cartons and Leftovers
#
# A supply room packs pencils into full cartons and records the pencils left over.
#
# **Specification:** Given the non-negative integers `pencils` and `carton_size`, use `//` to calculate full cartons and `%` to calculate leftovers. Print exactly `<cartons> cartons, <leftovers> left`.
#
# **Worked sample — given values:**
#
# ```python
# pencils = 137
# carton_size = 12
# ```
#
# **Expected output:**
#
# ```text
# 11 cartons, 5 left
# ```

# %%
pencils = 137
carton_size = 12

# Calculate both values and print the exact line.

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### While-Counter Pass Bar
#
# A practice robot must finish a fixed number of laps. This is a pass-bar question: the final count must come from a terminating `while` loop.
#
# **Specification:** Given the positive integer `lap_goal`, start `laps` at 0. Use `while laps < lap_goal:` and update `laps` with `laps = laps + 1`. After the loop, print exactly `Count: <laps>`.
#
# **Worked sample — given values:**
#
# ```python
# lap_goal = 9
# ```
#
# **Expected output:**
#
# ```text
# Count: 9
# ```

# %%
lap_goal = 9

# Count with a terminating while loop, then print one summary.

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Collatz Repeat-Until
#
# A positive number repeats the Collatz rule until a computed stop value appears: divide an even value by 2; otherwise multiply it by 3 and add 1.
#
# **Specification:** Given `n = 9`, set `steps` to 0.
# Use `while True:`.
# First test whether `n == 1` and `break` when it is.
# Otherwise apply the Collatz rule and add 1 to `steps`.
# After the loop, print exactly `Steps: <steps>`.
# The given start value is guaranteed to reach 1.
#
# **Worked sample — given values:**
#
# ```python
# n = 9
# ```
#
# **Expected output:**
#
# ```text
# Steps: 19
# ```

# %%
n = 9

# Repeat until n reaches 1; use while True and break.

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### For-Total Pass Bar
#
# A reading challenge awards every whole-number point value from 1 through a final day. This is a pass-bar question: use `for`, `range`, and a running total.
#
# **Specification:** Given the positive integer `last_day`, start `total` at 0. Use `for day in range(1, last_day + 1):` and add each `day` to `total`. After the loop, print exactly `Sum: <total>`.
#
# **Worked sample — given values:**
#
# ```python
# last_day = 20
# ```
#
# **Expected output:**
#
# ```text
# Sum: 210
# ```

# %%
last_day = 20

# Add 1 through last_day with for and range, then print one summary.

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Count by Condition
#
# A game awards a token on round numbers divisible by 7. The organizer needs the number of tokens awarded in the first 50 rounds.
#
# **Specification:** Use `for round_number in range(1, 51):`. Add 1 to `count` only when `round_number % 7 == 0`. After the loop, print exactly `Count: <count>`.
#
# **Worked sample — required interval:**
#
# ```text
# 1 through 50
# ```
#
# **Expected output:**
#
# ```text
# Count: 7
# ```

# %%
# Count round numbers divisible by 7, then print one summary.

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Six-by-Six Times Table
#
# A study sheet needs a multiplication table with six complete rows.
# Each row must be accumulated as a string before it is printed.
#
# **Specification:** Given `table_size = 6`, use nested `for` loops with outer variable `row` and inner variable `col`, each visiting 1 through `table_size`.
# Start `row_text` as an empty string for each outer pass.
# Accumulate the products with exactly one space between them.
# Print `row_text` once after the inner loop.
#
# **Worked sample — given values:**
#
# ```python
# table_size = 6
# ```
#
# **Expected output:**
#
# ```text
# 1 2 3 4 5 6
# 2 4 6 8 10 12
# 3 6 9 12 15 18
# 4 8 12 16 20 24
# 5 10 15 20 25 30
# 6 12 18 24 30 36
# ```

# %%
table_size = 6

# Build each table row as a string, then print it once.
