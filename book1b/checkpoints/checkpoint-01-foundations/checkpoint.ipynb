# %% [markdown]
# # Checkpoint 01: Foundations
#
# Complete all seven exercises. The balance is two output-and-variables exercises, two numbers-and-arithmetic exercises, two decisions exercises, and one traceback-reading exercise. Follow each specification and produce the exact output shown from the fixed given values.

# %% [markdown]
# <!--
# ## Question 1
# -->
#
# ## Exercise 1

# %% [markdown]
# ### Name Card
#
# A card stores a name and hometown separately, then places both values in one sentence.
#
# **Specification:** Given `name` and `hometown`, use one f-string to print exactly `<name> is from <hometown>.`
#
# **Worked sample — given values:**
#
# ```python
# name = "Maya"
# hometown = "Oakland"
# ```
#
# **Expected output:**
#
# ```text
# Maya is from Oakland.
# ```

# %%
name = "Maya"
hometown = "Oakland"

# Print the exact sentence with one f-string.

# %% [markdown]
# <!--
# ## Question 2
# -->
#
# ## Exercise 2

# %% [markdown]
# ### Labeled Item
#
# A shelf label joins fixed text with a saved item name.
#
# **Specification:** Given `item`, use string concatenation with `+` to print exactly `Item: <item>`. Do not use an f-string.
#
# **Worked sample — given values:**
#
# ```python
# item = "markers"
# ```
#
# **Expected output:**
#
# ```text
# Item: markers
# ```

# %%
item = "markers"

# Join the label and item, then print.

# %% [markdown]
# <!--
# ## Question 3
# -->
#
# ## Exercise 3

# %% [markdown]
# ### Hours and Minutes
#
# A duration needs complete hours and leftover minutes.
#
# **Specification:** Given the non-negative integer `total_minutes`, use `//` and `%` to print exactly `<hours> hours <minutes> minutes`.
#
# **Worked sample — given values:**
#
# ```python
# total_minutes = 155
# ```
#
# **Expected output:**
#
# ```text
# 2 hours 35 minutes
# ```

# %%
total_minutes = 155

# Calculate two new values and print the exact line.

# %% [markdown]
# <!--
# ## Question 4
# -->
#
# ## Exercise 4

# %% [markdown]
# ### Converted Average
#
# Two score values arrived as text. They must become integers before regular division finds their average.
#
# **Specification:** Given `first_text` and `second_text`, convert each with `int()`, add the numbers, divide by 2 with `/`, and print exactly `Average: <average>`. Show Python's exact float output.
#
# **Worked sample — given values:**
#
# ```python
# first_text = "8"
# second_text = "12"
# ```
#
# **Expected output:**
#
# ```text
# Average: 10.0
# ```

# %%
first_text = "8"
second_text = "12"

# Convert both values, calculate the average, and print.

# %% [markdown]
# <!--
# ## Question 5
# -->
#
# ## Exercise 5

# %% [markdown]
# ### Ordered Score Ladder
#
# A score receives the first level whose threshold it reaches. The checks overlap, so their order determines the label.
#
# **Specification:** Given `score`, use exactly one `if`/`elif`/`elif`/`else` ladder. Check `score >= 90` for `Level A` first, `score >= 80` for `Level B` next, and `score >= 70` for `Level C` next; otherwise print `Keep practicing`.
#
# **Worked sample — given values:**
#
# ```python
# score = 94
# ```
#
# **Expected output:**
#
# ```text
# Level A
# ```
#
# **Notice:** 94 also reaches the lower thresholds. The highest threshold must appear first because the first matching branch wins.

# %%
score = 94

# Check the thresholds from highest to lowest and print one label.

# %% [markdown]
# <!--
# ## Question 6
# -->
#
# ## Exercise 6

# %% [markdown]
# ### Range and Entry Test
#
# An entry is approved for ages 10 through 13 when the person also has either a pass or an invitation.
#
# **Specification:** Given `age`, `has_pass`, and `has_invitation`, use `age >= 10 and age <= 13` for the inclusive range. Join it with the choice `has_pass == True or has_invitation == True`, using parentheses to keep that choice together. Print `Entry approved` when the full condition is true; otherwise print `Entry denied`.
#
# **Worked sample — given values:**
#
# ```python
# age = 12
# has_pass = False
# has_invitation = True
# ```
#
# **Expected output:**
#
# ```text
# Entry approved
# ```

# %%
age = 12
has_pass = False
has_invitation = True

# Build the full and/or condition and print one message.

# %% [markdown]
# <!--
# ## Question 7
# -->
#
# ## Exercise 7

# %% [markdown]
# ### Read the Final Traceback Line
#
# A program tries to join text and an integer with `+`:
#
# ```python
# points = 7
# print("Points: " + points)
# ```
#
# The final traceback line begins like this:
#
# ```text
# TypeError: can only concatenate str ... to str
# ```
#
# **Specification:** Read the final traceback line and print only the error type.
#
# **Worked sample — given values:**
#
# ```text
# The final traceback line begins with TypeError.
# ```
#
# **Expected output:**
#
# ```text
# TypeError
# ```

# %%
# Print only the error type named by the final traceback line.
