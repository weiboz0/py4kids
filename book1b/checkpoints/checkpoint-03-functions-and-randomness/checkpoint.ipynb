# %% [markdown]
# # Checkpoint 03: Functions & Randomness
#
# Complete all seven questions. Define each requested function, return its result, and use the worked calls to check your work. Questions use only numbers and ordinary text labels; do not use collections. Do not use `input()`.

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Prime Test
#
# **Specification:** Define `is_prime(n)`. Return `False` when `n < 2`. Otherwise start a local name `divisor` at 2 and use a `while` loop to test every divisor smaller than `n`. Return `False` if any divisor divides evenly; otherwise return `True` after the loop.
#
# **Worked sample calls:**
#
# ```text
# is_prime(1)  → False
# is_prime(9)  → False
# is_prime(19) → True
# ```

# %%
# Define is_prime(n) below.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Parameterized Travel Cost
#
# **Specification:** Define `travel_cost(km_text, rate_text)`. Inside the function, convert the parameters with `km = float(km_text)` and `rate = float(rate_text)`, then set the local name `base = 3.5`. Return `round(base + km * rate, 2)`. Then call the function for `"8"` kilometres at a rate of `"1.25"`. Save the result with `cost = travel_cost("8", "1.25")`, then print it with `print(f"Trip cost: ${cost}")`.
#
# **Worked sample calls:**
#
# ```text
# travel_cost("8", "1.25") → 13.5
# travel_cost("15", "0.8") → 15.5
# travel_cost("0", "2.5")  → 3.5
# ```
#
# **Expected printed line:**
#
# ```text
# Trip cost: $13.5
# ```

# %%
# Define travel_cost(km_text, rate_text), then call and print its result.

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Running-Total Function
#
# **Specification:** Define `sum_to_n(n)`. Start `total` at 0. Use `for number in range(1, n + 1):` and update the running total with `total = total + number`. Return `total`.
#
# **Worked sample calls:**
#
# ```text
# sum_to_n(3)  → 6
# sum_to_n(7)  → 28
# sum_to_n(20) → 210
# ```

# %%
# Define sum_to_n(n) below.

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Count Primes
#
# **Specification:** Keep your `is_prime(n)` function from Question 1. Define `count_primes(n)`. Use `for candidate in range(2, n + 1):` and call `is_prime(candidate)`. Add 1 to `total` only when that call returns `True`. Return the count.
#
# **Worked sample calls:**
#
# ```text
# count_primes(5)  → 3
# count_primes(10) → 4
# count_primes(20) → 8
# ```

# %%
# Define count_primes(n) below and call is_prime(candidate).

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Award Ladder
#
# **Specification:** Define `award_level(points)` with exactly one `if`/`elif`/`elif`/`else` ladder. Return `"Gold"` for at least 90 points, `"Silver"` for at least 70, `"Bronze"` for at least 50, and `"Keep practicing"` otherwise. Check thresholds from highest to lowest. Do not join text with `+`.
#
# **Worked sample calls:**
#
# ```text
# award_level(93) → "Gold"
# award_level(74) → Silver
# award_level(58) → Bronze
# award_level(30) → Keep practicing
# ```

# %%
# Define award_level(points) below.

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Number-Tool Score
#
# **Specification:** Define `balanced_score(a, b, c)`. Use `max(max(a, b), c)` for `high`, `min(a, b, c)` for `low`, `abs(high - low)` for `spread`, and `sum(range(1, 4))` for `bonus`. Return `round((a + b + c + bonus - spread) / 3, 1)`.
#
# **Worked sample calls:**
#
# ```text
# balanced_score(8, 12, 10) → 10.7
# balanced_score(20, 5, 11) → 9.0
# balanced_score(7, 7, 7)   → 9.0
# ```

# %%
# Define balanced_score(a, b, c) below.

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Seeded High-Roll Count
#
# **Specification:** Begin with `import random` using module style. Define `count_high_rolls(trials)`. Inside the function, call `random.seed(4)` **before the first random use** so the answer is reproducible. Start `total` at 0. Roll with `random.randint(1, 6)` exactly `trials` times and add 1 when the roll is at least 5. Return `total`.
#
# **Worked sample calls:**
#
# ```text
# count_high_rolls(5)  → 1
# count_high_rolls(12) → 2
# count_high_rolls(30) → 5
# ```

# %%
import random

# Define count_high_rolls(trials) below. Seed with 4 before its first random use.
